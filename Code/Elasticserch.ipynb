# %% [markdown]
# # Elasticsearch Pratice
# __Author__: Jingkai Sun

# %%
from elasticsearch import Elasticsearch as es

# %%
es = es(HOST = 'http://localhost', PORT = 9200)

# %%
es.indices.create(index = 'first_index', ignore = 400)
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'first_index'}

# %%
es.indices.exists(index = 'first_index')
# Out:
# True

# %%
es.indices.delete(index = 'first_index')
# Out:
# {'acknowledged': True}

# %%
es.indices.exists(index = 'first_index')
# Out:
# False

# %% [markdown]
# # Insert and get query

# %%
doc1 = {"city": "New Delhi", "country": "India"}
doc2 = {'city': "London", "country": "England"}
doc3 = {'city': "Los Angeles", "country": "USA"}
doc4 = {'city': 'Beijing', 'country': 'China'}

# %%
es.index(index = "cities", doc_type = "places", id = 1, body = doc1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/elasticsearch/connection/base.py:177: ElasticsearchDeprecationWarning: [types removal] Specifying types in document index requests is deprecated, use the typeless endpoints instead (/{index}/_doc/{id}, /{index}/_doc, or /{index}/_create/{id}).
#   warnings.warn(message, category=ElasticsearchDeprecationWarning)
# {'_index': 'cities',
#  '_type': 'places',
#  '_id': '1',
#  '_version': 6,
#  'result': 'updated',
#  '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#  '_seq_no': 8,
#  '_primary_term': 1}

# %%
es.index(index = "cities", doc_type = "places", id = 2, body = doc2)
# Out:
# {'_index': 'cities',
#  '_type': 'places',
#  '_id': '2',
#  '_version': 2,
#  'result': 'updated',
#  '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#  '_seq_no': 9,
#  '_primary_term': 1}

# %%
es.index(index = "cities", doc_type = "places", id = 3, body = doc3)
es.index(index = "cities", doc_type = "places", id = 4, body = doc4)
# Out:
# {'_index': 'cities',
#  '_type': 'places',
#  '_id': '4',
#  '_version': 2,
#  'result': 'updated',
#  '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#  '_seq_no': 11,
#  '_primary_term': 1}

# %%
res = es.get(index = 'cities', doc_type = 'places', id = 3)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/elasticsearch/connection/base.py:177: ElasticsearchDeprecationWarning: [types removal] Specifying types in document get requests is deprecated, use the /{index}/_doc/{id} endpoint instead.
#   warnings.warn(message, category=ElasticsearchDeprecationWarning)

# %%
res
# Out:
# {'_index': 'cities',
#  '_type': 'places',
#  '_id': '3',
#  '_version': 2,
#  '_seq_no': 10,
#  '_primary_term': 1,
#  'found': True,
#  '_source': {'city': 'Los Angeles', 'country': 'USA'}}

# %%
res['_source']
# Out:
# {'city': 'Los Angeles', 'country': 'USA'}

# %% [markdown]
# # Different search query for matching documents

# %%
doc1 = {"sentence": "Today is a sunny day."}
doc2 = {"sentence": "Today is a bright-sunny day"}

# %%
es.index(index = "english", doc_type = "sentences", id = 1, body = doc1)
# Out:
# {'_index': 'english',
#  '_type': 'sentences',
#  '_id': '1',
#  '_version': 3,
#  'result': 'updated',
#  '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#  '_seq_no': 4,
#  '_primary_term': 1}

# %%
es.index(index = "english", doc_type = "sentences", id = 2, body = doc2)
# Out:
# {'_index': 'english',
#  '_type': 'sentences',
#  '_id': '2',
#  '_version': 2,
#  'result': 'updated',
#  '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#  '_seq_no': 5,
#  '_primary_term': 1}

# %%
res = es.search(index = 'english', body = {'from': 0, "size": 0, "query": {
    "match": {"sentence": "SUNNY"}
    }})

# %%
res
#insensitive to uppercase or lowercase
# Out:
# {'took': 526,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 2, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []}}

# %%
res_match_phrase = es.search(index = 'english', body = {'from': 0, "size": 0, "query": {
    "match_phrase": {"sentence": "bright SUNNY"}
    }})

# %%
res_match_phrase
#Match phrase: nont only matches the individual token but also the relative ordering
# Out:
# {'took': 2,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []}}

# %%
res_term = es.search(index = 'english', body = {'from': 0, "size": 1, "query": {
    "term": {"sentence": "bright SUNNY"}
    }})

# %%
res_term
# Out:
# {'took': 1,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 0, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []}}

# %% [markdown]
# # Combining queries

# %%
# must, must_not, should
res = es.search(index = "english", body = {"from": 0, "size": 1, "query": {"bool": {
                                                                            "must_not": {
                                                                                "match":{
                                                                                    "sentence": "bright"
                                                                                }
                                                                          },
                                                                            "should": {
                                                                                "match":{
                                                                                    "sentence": "sunny"
                                                                                }
                                                                            }
}}})

# %%
res
# Out:
# {'took': 3,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1, 'relation': 'eq'},
#   'max_score': 0.4823361,
#   'hits': [{'_index': 'english',
#     '_type': 'sentences',
#     '_id': '1',
#     '_score': 0.4823361,
#     '_source': {'sentence': 'Today is a sunny day.'}}]}}

# %% [markdown]
# # Regular Expressions in Elasticsearch

# %%
doc3 = {'sentence': "Today is a rainy day"}

# %%
es.index(index = 'english', doc_type = 'sentences', id = 3, body  = doc3)
# Out:
# {'_index': 'english',
#  '_type': 'sentences',
#  '_id': '3',
#  '_version': 2,
#  'result': 'updated',
#  '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#  '_seq_no': 6,
#  '_primary_term': 1}

# %%
es.get(index = 'english', doc_type = "sentences", id = 3)
# Out:
# {'_index': 'english',
#  '_type': 'sentences',
#  '_id': '3',
#  '_version': 2,
#  '_seq_no': 6,
#  '_primary_term': 1,
#  'found': True,
#  '_source': {'sentence': 'Today is a rainy day'}}

# %%
# match everything
es.search(index = 'english', body = {"from": 0, "size": 5, "query":{"regexp":{"sentence": ".*"}}})
# Out:
# {'took': 3,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 3, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'english',
#     '_type': 'sentences',
#     '_id': '1',
#     '_score': 1.0,
#     '_source': {'sentence': 'Today is a sunny day.'}},
#    {'_index': 'english',
#     '_type': 'sentences',
#     '_id': '2',
#     '_score': 1.0,
#     '_source': {'sentence': 'Today is a bright-sunny day'}},
#    {'_index': 'english',
#     '_type': 'sentences',
#     '_id': '3',
#     '_score': 1.0,
#     '_source': {'sentence': 'Today is a rainy day'}}]}}

# %%
es.search(index = 'english', body = {"from": 0, "size": 5, "query":{"regexp":{"sentence": "sun.*"}}})
# Out:
# {'took': 4,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 2, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'english',
#     '_type': 'sentences',
#     '_id': '1',
#     '_score': 1.0,
#     '_source': {'sentence': 'Today is a sunny day.'}},
#    {'_index': 'english',
#     '_type': 'sentences',
#     '_id': '2',
#     '_score': 1.0,
#     '_source': {'sentence': 'Today is a bright-sunny day'}}]}}

# %% [markdown]
# # Mapping

# %% [markdown]
# ## What is Mapping?
# as per Elasticsearch Reference, "Mapping is the process of defining how a document, and the fields it contains, are stored and indexed"

# %% [markdown]
# ## How does it help?
# It enables in faster search retrieval and aggregations. Hence, your mapping defines how effectively you can handle your data. A bad mapping can have severe consequences on the performance of your system

# %%
#documents to insert in the elasticsearch index "cities"
doc1 = {'city': "Bangalore", "country": "India", "datetime": "2018,01,01,10,20,00"}
doc2 = {'city': "London", "country": "England", "datetime": "2018,01,02,03,12,00"}
doc3 = {'city': "Los Angeles", "country": "USA", "datetime": "2018,04,19,12,02,00"}
doc4 = {'city': "Shanghai", "country": "China", "datetime": "2018,05,12,03,30,00"}

# %%
es.index(index = 'travel', doc_type = 'cities', id = 1, body = doc1)
es.index(index = 'travel', doc_type = 'cities', id = 2, body = doc2)
es.index(index = 'travel', doc_type = 'cities', id = 3, body = doc3)
es.index(index = 'travel', doc_type = 'cities', id = 4, body = doc4)
# Out:
# {'_index': 'travel',
#  '_type': 'cities',
#  '_id': '4',
#  '_version': 3,
#  'result': 'updated',
#  '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#  '_seq_no': 14,
#  '_primary_term': 1}

# %%
es.indices.get_mapping(index = 'travel', doc_type = 'cities', include_type_name=True) #POSTMAN: http://127.0.0.1:9200/travel/_mapping/cities
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/elasticsearch/connection/base.py:177: ElasticsearchDeprecationWarning: [types removal] Using include_type_name in get mapping requests is deprecated. The parameter will be removed in the next major version.
#   warnings.warn(message, category=ElasticsearchDeprecationWarning)
# {'travel': {'mappings': {'cities': {'properties': {'city': {'type': 'text',
#       'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#      'country': {'type': 'text',
#       'fields': {'keyword': {'type': 'keyword', 'ignore_above': 256}}},
#      'datetime': {'type': 'date', 'format': 'yyyy,MM,dd,hh,mm,ss'}}}}}}

# %%
es.indices.delete(index = "travel") #MUST delete automatic mappings before cutomising the mappings
# Out:
# {'acknowledged': True}

# %%
es.indices.create(index = "travel")
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'travel'}

# %%
#http://127.0.0.1:9200/travel/_mapping/places
es.indices.put_mapping(
    index = "travel",
    doc_type = "cities",
    body = 
        {
            "properties" : {
                "city":{
                    "type": "text",
                    "fields": {
                        "keyword": {
                            "type": "keyword",
                            "ignore_above": 256
                        }
                    }
                },
                "country": {
                    "type": "text",
                    "fields": {
                        "keyword": {
                            "type": "keyword",
                            "ignore_above": 256
                        }
                    }
                },
                "datetime": {
                    "type": "date",
                    "format": "yyyy,MM,dd,hh,mm,ss"
                }
            }
        },
    include_type_name = True
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/elasticsearch/connection/base.py:177: ElasticsearchDeprecationWarning: [types removal] Using include_type_name in put mapping requests is deprecated. The parameter will be removed in the next major version.
#   warnings.warn(message, category=ElasticsearchDeprecationWarning)
# {'acknowledged': True}

# %% [markdown]
# # Date Histogram Aggregations

# %% [markdown]
# Aggregations are one of the most important application of Elasticsearch. It provides you with quick powerful analysis of your data! Below we have discussed aggregations over date values.
#
# A lot of analysis happen on a time-series scales. For example: Quaterly of iphone cross the world. Therefore it is essential to have an fast aggregation done over large dataset under different granular scales. ES provides such an aggregation via date histogram aggregation. The granulation over which you can do aggregations are:
#
# 1. year
# 2. quater
# 3. month
# 4. hour
# 5. week
# 6. day
# 7. hour
# 8. minute
# 9. second
# 10. milisecond

# %%
es.search(index = "travel", body = {"from": 0, "size": 5, "query": {"match_all": {}}})
# Out:
# {'took': 1,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 0, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []}}

# %%
es.search(index = "travel", 
          body = {"from": 0, "size": 0, "query":{"match_all":{}}, "aggs": {
            "country": {
                "date_histogram": {"field": "datetime", "interval": "month"}}}})
#根据year，count数据个数
#summirization
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/elasticsearch/connection/base.py:177: ElasticsearchDeprecationWarning: [interval] on [date_histogram] is deprecated, use [fixed_interval] or [calendar_interval] in the future.
#   warnings.warn(message, category=ElasticsearchDeprecationWarning)
# {'took': 2,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 0, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'country': {'buckets': []}}}

# %%
doc4 = {"city":"Sydney", "country": "Australia", "datetime":"2019,01,01,10,20,00"}
es.index(index= "travel", doc_type = "cities", id = 5, body = doc4)
# Out:
# {'_index': 'travel',
#  '_type': 'cities',
#  '_id': '5',
#  '_version': 1,
#  'result': 'created',
#  '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#  '_seq_no': 0,
#  '_primary_term': 1}

# %%
es.search(index = "travel", body = {"from": 0, "size": 5, "query": {"match_all": {}}})
# Out:
# {'took': 1,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'travel',
#     '_type': 'cities',
#     '_id': '5',
#     '_score': 1.0,
#     '_source': {'city': 'Sydney',
#      'country': 'Australia',
#      'datetime': '2019,01,01,10,20,00'}}]}}

# %% [markdown]
# # Bulk Insert and Scan

# %%
from datetime import datetime
from elasticsearch import helpers as hprs
import time

# %%
# Bulk inserts snippet with time calculation to insert
#批量插入

action = [
    {
        "_index": "chapter8",
        "_type": "doc",
        "_id": j,
        "_source": {
            "any": "data" + str(j),
            "timestamp": datetime.now()
        }
    }
    for j in range(0, 10000)
]

st = time.time()
hprs.bulk(es, action)
end = time.time()
print("total time: ", end - st)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/elasticsearch/connection/base.py:177: ElasticsearchDeprecationWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchDeprecationWarning)
# total time:  1.0638988018035889

# %%
# Insertion iteratively: same effect as above but more INEFFICIENT !!!
st = time.time()
for j in range(0,100):
    doc = {
        "any": "data" + str(j),
        "timestamp": datetime.now()
    }
    es.index(index = 'chapter8', doc_type = "doc", id = j, body = doc)
end = time.time()
print("total time", end - st)
# Out:
# total time 3.2384350299835205

# %%
es.search(index = "chapter8", body = {"from": 0, "size": 5, "query": {"match_all": {}}})
# Out:
# {'took': 448,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'chapter8',
#     '_type': 'doc',
#     '_id': '100',
#     '_score': 1.0,
#     '_source': {'any': 'data100', 'timestamp': '2020-08-09T10:38:05.055040'}},
#    {'_index': 'chapter8',
#     '_type': 'doc',
#     '_id': '101',
#     '_score': 1.0,
#     '_source': {'any': 'data101', 'timestamp': '2020-08-09T10:38:05.055041'}},
#    {'_index': 'chapter8',
#     '_type': 'doc',
#     '_id': '102',
#     '_score': 1.0,
#     '_source': {'any': 'data102', 'timestamp': '2020-08-09T10:38:05.055043'}},
#    {'_index': 'chapter8',
#     '_type': 'doc',
#     '_id': '103',
#     '_score': 1.0,
#     '_source': {'any': 'data103', 'timestamp': '2020-08-09T10:38:05.055044'}},
#    {'_index': 'chapter8',
#     '_type': 'doc',
#     '_id': '104',
#     '_score': 1.0,
#     '_source': {'any': 'data104',
#      'timestamp': '2020-08-09T10:38:05.055045'}}]}}

# %%
# Scanning over large data (very quickly!!!)
results = hprs.scan(es, index = "chapter8", doc_type = "doc", query = {"query": {"match_all": {}}})
for item in results:
    print(item["_id"], item["_source"])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/elasticsearch/connection/base.py:177: ElasticsearchDeprecationWarning: [types removal] Specifying types in search requests is deprecated.
#   warnings.warn(message, category=ElasticsearchDeprecationWarning)
# 100 {'any': 'data100', 'timestamp': '2020-08-09T10:38:05.055040'}
# 101 {'any': 'data101', 'timestamp': '2020-08-09T10:38:05.055041'}
# 102 {'any': 'data102', 'timestamp': '2020-08-09T10:38:05.055043'}
# 103 {'any': 'data103', 'timestamp': '2020-08-09T10:38:05.055044'}
# 104 {'any': 'data104', 'timestamp': '2020-08-09T10:38:05.055045'}
# 105 {'any': 'data105', 'timestamp': '2020-08-09T10:38:05.055047'}
# 106 {'any': 'data106', 'timestamp': '2020-08-09T10:38:05.055048'}
# 107 {'any': 'data107', 'timestamp': '2020-08-09T10:38:05.055050'}
# 108 {'any': 'data108', 'timestamp': '2020-08-09T10:38:05.055053'}
# 109 {'any': 'data109', 'timestamp': '2020-08-09T10:38:05.055054'}
# 110 {'any': 'data110', 'timestamp': '2020-08-09T10:38:05.055056'}
# 111 {'any': 'data111', 'timestamp': '2020-08-09T10:38:05.055057'}
# 112 {'any': 'data112', 'timestamp': '2020-08-09T10:38:05.055058'}
# 113 {'any': 'data113', 'timestamp': '2020-08-09T10:38:05.055060'}
# 114 {'any': 'data114', 'timestamp': '2020-08-09T10:38:05.055061'}
# 115 {'any': 'data115', 'timestamp': '2020-08-09T10:38:05.055062'}
# 116 {'any': 'data116', 'timestamp': '2020-08-09T10:38:05.055064'}
# 117 {'any': 'data117', 'timestamp': '2020-08-09T10:38:05.055065'}
# 118 {'any': 'data118', 'timestamp': '2020-08-09T10:38:05.055067'}
# 119 {'any': 'data119', 'timestamp': '2020-08-09T10:38:05.055068'}
# 120 {'any': 'data120', 'timestamp': '2020-08-09T10:38:05.055071'}
# 121 {'any': 'data121', 'timestamp': '2020-08-09T10:38:05.055074'}
# 122 {'any': 'data122', 'timestamp': '2020-08-09T10:38:05.055076'}
# 123 {'any': 'data123', 'timestamp': '2020-08-09T10:38:05.055077'}
# 124 {'any': 'data124', 'timestamp': '2020-08-09T10:38:05.055079'}
# 125 {'any': 'data125', 'timestamp': '2020-08-09T10:38:05.055080'}
# 126 {'any': 'data126', 'timestamp': '2020-08-09T10:38:05.055081'}
# 127 {'any': 'data127', 'timestamp': '2020-08-09T10:38:05.055084'}
# 128 {'any': 'data128', 'timestamp': '2020-08-09T10:38:05.055085'}
# 129 {'any': 'data129', 'timestamp': '2020-08-09T10:38:05.055086'}
# 130 {'any': 'data130', 'timestamp': '2020-08-09T10:38:05.055088'}
# 131 {'any': 'data131', 'timestamp': '2020-08-09T10:38:05.055089'}
# 132 {'any': 'data132', 'timestamp': '2020-08-09T10:38:05.055092'}
# 133 {'any': 'data133', 'timestamp': '2020-08-09T10:38:05.055094'}
# 134 {'any': 'data134', 'timestamp': '2020-08-09T10:38:05.055095'}
# 135 {'any': 'data135', 'timestamp': '2020-08-09T10:38:05.055096'}
# 136 {'any': 'data136', 'timestamp': '2020-08-09T10:38:05.055098'}
# 137 {'any': 'data137', 'timestamp': '2020-08-09T10:38:05.055099'}
# 138 {'any': 'data138', 'timestamp': '2020-08-09T10:38:05.055100'}
# 139 {'any': 'data139', 'timestamp': '2020-08-09T10:38:05.055102'}
# 140 {'any': 'data140', 'timestamp': '2020-08-09T10:38:05.055103'}
# 141 {'any': 'data141', 'timestamp': '2020-08-09T10:38:05.055105'}
# 142 {'any': 'data142', 'timestamp': '2020-08-09T10:38:05.055106'}
# 143 {'any': 'data143', 'timestamp': '2020-08-09T10:38:05.055109'}
# 144 {'any': 'data144', 'timestamp': '2020-08-09T10:38:05.055113'}
# 145 {'any': 'data145', 'timestamp': '2020-08-09T10:38:05.055114'}
# 146 {'any': 'data146', 'timestamp': '2020-08-09T10:38:05.055116'}
# 147 {'any': 'data147', 'timestamp': '2020-08-09T10:38:05.055117'}
# 148 {'any': 'data148', 'timestamp': '2020-08-09T10:38:05.055118'}
# 149 {'any': 'data149', 'timestamp': '2020-08-09T10:38:05.055122'}
# 150 {'any': 'data150', 'timestamp': '2020-08-09T10:38:05.055123'}
# 151 {'any': 'data151', 'timestamp': '2020-08-09T10:38:05.055124'}
# 152 {'any': 'data152', 'timestamp': '2020-08-09T10:38:05.055127'}
# 153 {'any': 'data153', 'timestamp': '2020-08-09T10:38:05.055129'}
# 154 {'any': 'data154', 'timestamp': '2020-08-09T10:38:05.055130'}
# 155 {'any': 'data155', 'timestamp': '2020-08-09T10:38:05.055132'}
# 156 {'any': 'data156', 'timestamp': '2020-08-09T10:38:05.055135'}
# 157 {'any': 'data157', 'timestamp': '2020-08-09T10:38:05.055136'}
# 158 {'any': 'data158', 'timestamp': '2020-08-09T10:38:05.055138'}
# 159 {'any': 'data159', 'timestamp': '2020-08-09T10:38:05.055139'}
# 160 {'any': 'data160', 'timestamp': '2020-08-09T10:38:05.055140'}
# 161 {'any': 'data161', 'timestamp': '2020-08-09T10:38:05.055142'}
# 162 {'any': 'data162', 'timestamp': '2020-08-09T10:38:05.055143'}
# 163 {'any': 'data163', 'timestamp': '2020-08-09T10:38:05.055262'}
# 164 {'any': 'data164', 'timestamp': '2020-08-09T10:38:05.055264'}
# 165 {'any': 'data165', 'timestamp': '2020-08-09T10:38:05.055265'}
# 166 {'any': 'data166', 'timestamp': '2020-08-09T10:38:05.055267'}
# 167 {'any': 'data167', 'timestamp': '2020-08-09T10:38:05.055268'}
# 168 {'any': 'data168', 'timestamp': '2020-08-09T10:38:05.055273'}
# 169 {'any': 'data169', 'timestamp': '2020-08-09T10:38:05.055274'}
# 170 {'any': 'data170', 'timestamp': '2020-08-09T10:38:05.055275'}
# 171 {'any': 'data171', 'timestamp': '2020-08-09T10:38:05.055277'}
# 172 {'any': 'data172', 'timestamp': '2020-08-09T10:38:05.055278'}
# 173 {'any': 'data173', 'timestamp': '2020-08-09T10:38:05.055279'}
# 174 {'any': 'data174', 'timestamp': '2020-08-09T10:38:05.055281'}
# 175 {'any': 'data175', 'timestamp': '2020-08-09T10:38:05.055283'}
# 176 {'any': 'data176', 'timestamp': '2020-08-09T10:38:05.055284'}
# 177 {'any': 'data177', 'timestamp': '2020-08-09T10:38:05.055287'}
# 178 {'any': 'data178', 'timestamp': '2020-08-09T10:38:05.055288'}
# 179 {'any': 'data179', 'timestamp': '2020-08-09T10:38:05.055290'}
# 180 {'any': 'data180', 'timestamp': '2020-08-09T10:38:05.055293'}
# 181 {'any': 'data181', 'timestamp': '2020-08-09T10:38:05.055294'}
# 182 {'any': 'data182', 'timestamp': '2020-08-09T10:38:05.055296'}
# 183 {'any': 'data183', 'timestamp': '2020-08-09T10:38:05.055297'}
# 184 {'any': 'data184', 'timestamp': '2020-08-09T10:38:05.055298'}
# 185 {'any': 'data185', 'timestamp': '2020-08-09T10:38:05.055300'}
# 186 {'any': 'data186', 'timestamp': '2020-08-09T10:38:05.055301'}
# 187 {'any': 'data187', 'timestamp': '2020-08-09T10:38:05.055302'}
# 188 {'any': 'data188', 'timestamp': '2020-08-09T10:38:05.055304'}
# 189 {'any': 'data189', 'timestamp': '2020-08-09T10:38:05.055305'}
# 190 {'any': 'data190', 'timestamp': '2020-08-09T10:38:05.055306'}
# 191 {'any': 'data191', 'timestamp': '2020-08-09T10:38:05.055308'}
# 192 {'any': 'data192', 'timestamp': '2020-08-09T10:38:05.055311'}
# 193 {'any': 'data193', 'timestamp': '2020-08-09T10:38:05.055312'}
# 194 {'any': 'data194', 'timestamp': '2020-08-09T10:38:05.055313'}
# 195 {'any': 'data195', 'timestamp': '2020-08-09T10:38:05.055315'}
# 196 {'any': 'data196', 'timestamp': '2020-08-09T10:38:05.055316'}
# 197 {'any': 'data197', 'timestamp': '2020-08-09T10:38:05.055317'}
# 198 {'any': 'data198', 'timestamp': '2020-08-09T10:38:05.055319'}
# 199 {'any': 'data199', 'timestamp': '2020-08-09T10:38:05.055320'}
# 200 {'any': 'data200', 'timestamp': '2020-08-09T10:38:05.055321'}
# 201 {'any': 'data201', 'timestamp': '2020-08-09T10:38:05.055323'}
# 202 {'any': 'data202', 'timestamp': '2020-08-09T10:38:05.055324'}
# 203 {'any': 'data203', 'timestamp': '2020-08-09T10:38:05.055326'}
# 204 {'any': 'data204', 'timestamp': '2020-08-09T10:38:05.055329'}
# 205 {'any': 'data205', 'timestamp': '2020-08-09T10:38:05.055332'}
# 206 {'any': 'data206', 'timestamp': '2020-08-09T10:38:05.055334'}
# 207 {'any': 'data207', 'timestamp': '2020-08-09T10:38:05.055335'}
# 208 {'any': 'data208', 'timestamp': '2020-08-09T10:38:05.055336'}
# 209 {'any': 'data209', 'timestamp': '2020-08-09T10:38:05.055338'}
# 210 {'any': 'data210', 'timestamp': '2020-08-09T10:38:05.055339'}
# 211 {'any': 'data211', 'timestamp': '2020-08-09T10:38:05.055340'}
# 212 {'any': 'data212', 'timestamp': '2020-08-09T10:38:05.055342'}
# 213 {'any': 'data213', 'timestamp': '2020-08-09T10:38:05.055343'}
# 214 {'any': 'data214', 'timestamp': '2020-08-09T10:38:05.055344'}
# 215 {'any': 'data215', 'timestamp': '2020-08-09T10:38:05.055347'}
# 216 {'any': 'data216', 'timestamp': '2020-08-09T10:38:05.055350'}
# 217 {'any': 'data217', 'timestamp': '2020-08-09T10:38:05.055352'}
# 218 {'any': 'data218', 'timestamp': '2020-08-09T10:38:05.055353'}
# 219 {'any': 'data219', 'timestamp': '2020-08-09T10:38:05.055354'}
# 220 {'any': 'data220', 'timestamp': '2020-08-09T10:38:05.055356'}
# 221 {'any': 'data221', 'timestamp': '2020-08-09T10:38:05.055357'}
# 222 {'any': 'data222', 'timestamp': '2020-08-09T10:38:05.055358'}
# 223 {'any': 'data223', 'timestamp': '2020-08-09T10:38:05.055360'}
# 224 {'any': 'data224', 'timestamp': '2020-08-09T10:38:05.055361'}
# 225 {'any': 'data225', 'timestamp': '2020-08-09T10:38:05.055362'}
# 226 {'any': 'data226', 'timestamp': '2020-08-09T10:38:05.055364'}
# 227 {'any': 'data227', 'timestamp': '2020-08-09T10:38:05.055365'}
# 228 {'any': 'data228', 'timestamp': '2020-08-09T10:38:05.055369'}
# 229 {'any': 'data229', 'timestamp': '2020-08-09T10:38:05.055370'}
# 230 {'any': 'data230', 'timestamp': '2020-08-09T10:38:05.055371'}
# 231 {'any': 'data231', 'timestamp': '2020-08-09T10:38:05.055373'}
# 232 {'any': 'data232', 'timestamp': '2020-08-09T10:38:05.055374'}
# 233 {'any': 'data233', 'timestamp': '2020-08-09T10:38:05.055377'}
# 234 {'any': 'data234', 'timestamp': '2020-08-09T10:38:05.055379'}
# 235 {'any': 'data235', 'timestamp': '2020-08-09T10:38:05.055380'}
# 236 {'any': 'data236', 'timestamp': '2020-08-09T10:38:05.055381'}
# 237 {'any': 'data237', 'timestamp': '2020-08-09T10:38:05.055383'}
# 238 {'any': 'data238', 'timestamp': '2020-08-09T10:38:05.055384'}
# 239 {'any': 'data239', 'timestamp': '2020-08-09T10:38:05.055385'}
# 240 {'any': 'data240', 'timestamp': '2020-08-09T10:38:05.055388'}
# 241 {'any': 'data241', 'timestamp': '2020-08-09T10:38:05.055390'}
# 242 {'any': 'data242', 'timestamp': '2020-08-09T10:38:05.055391'}
# 243 {'any': 'data243', 'timestamp': '2020-08-09T10:38:05.055392'}
# 244 {'any': 'data244', 'timestamp': '2020-08-09T10:38:05.055394'}
# 245 {'any': 'data245', 'timestamp': '2020-08-09T10:38:05.055395'}
# 246 {'any': 'data246', 'timestamp': '2020-08-09T10:38:05.055397'}
# 247 {'any': 'data247', 'timestamp': '2020-08-09T10:38:05.055398'}
# 248 {'any': 'data248', 'timestamp': '2020-08-09T10:38:05.055399'}
# 249 {'any': 'data249', 'timestamp': '2020-08-09T10:38:05.055401'}
# 250 {'any': 'data250', 'timestamp': '2020-08-09T10:38:05.055402'}
# 251 {'any': 'data251', 'timestamp': '2020-08-09T10:38:05.055403'}
# 252 {'any': 'data252', 'timestamp': '2020-08-09T10:38:05.055406'}
# 253 {'any': 'data253', 'timestamp': '2020-08-09T10:38:05.055410'}
# 254 {'any': 'data254', 'timestamp': '2020-08-09T10:38:05.055411'}
# 255 {'any': 'data255', 'timestamp': '2020-08-09T10:38:05.055413'}
# 256 {'any': 'data256', 'timestamp': '2020-08-09T10:38:05.055414'}
# 257 {'any': 'data257', 'timestamp': '2020-08-09T10:38:05.055415'}
# 258 {'any': 'data258', 'timestamp': '2020-08-09T10:38:05.055417'}
# 259 {'any': 'data259', 'timestamp': '2020-08-09T10:38:05.055418'}
# 260 {'any': 'data260', 'timestamp': '2020-08-09T10:38:05.055419'}
# 261 {'any': 'data261', 'timestamp': '2020-08-09T10:38:05.055422'}
# 262 {'any': 'data262', 'timestamp': '2020-08-09T10:38:05.055424'}
# 263 {'any': 'data263', 'timestamp': '2020-08-09T10:38:05.055425'}
# 264 {'any': 'data264', 'timestamp': '2020-08-09T10:38:05.055428'}
# 265 {'any': 'data265', 'timestamp': '2020-08-09T10:38:05.055429'}
# 266 {'any': 'data266', 'timestamp': '2020-08-09T10:38:05.055431'}
# 267 {'any': 'data267', 'timestamp': '2020-08-09T10:38:05.055432'}
# 268 {'any': 'data268', 'timestamp': '2020-08-09T10:38:05.055433'}
# 269 {'any': 'data269', 'timestamp': '2020-08-09T10:38:05.055435'}
# 270 {'any': 'data270', 'timestamp': '2020-08-09T10:38:05.055436'}
# 271 {'any': 'data271', 'timestamp': '2020-08-09T10:38:05.055438'}
# 272 {'any': 'data272', 'timestamp': '2020-08-09T10:38:05.055439'}
# 273 {'any': 'data273', 'timestamp': '2020-08-09T10:38:05.055440'}
# 274 {'any': 'data274', 'timestamp': '2020-08-09T10:38:05.055442'}
# 275 {'any': 'data275', 'timestamp': '2020-08-09T10:38:05.055443'}
# 276 {'any': 'data276', 'timestamp': '2020-08-09T10:38:05.055446'}
# 277 {'any': 'data277', 'timestamp': '2020-08-09T10:38:05.055448'}
# 278 {'any': 'data278', 'timestamp': '2020-08-09T10:38:05.055449'}
# 279 {'any': 'data279', 'timestamp': '2020-08-09T10:38:05.055450'}
# 280 {'any': 'data280', 'timestamp': '2020-08-09T10:38:05.055452'}
# 281 {'any': 'data281', 'timestamp': '2020-08-09T10:38:05.055453'}
# 282 {'any': 'data282', 'timestamp': '2020-08-09T10:38:05.055454'}
# 283 {'any': 'data283', 'timestamp': '2020-08-09T10:38:05.055456'}
# 284 {'any': 'data284', 'timestamp': '2020-08-09T10:38:05.055457'}
# 285 {'any': 'data285', 'timestamp': '2020-08-09T10:38:05.055458'}
# 286 {'any': 'data286', 'timestamp': '2020-08-09T10:38:05.055460'}
# 287 {'any': 'data287', 'timestamp': '2020-08-09T10:38:05.055463'}
# 288 {'any': 'data288', 'timestamp': '2020-08-09T10:38:05.055466'}
# 289 {'any': 'data289', 'timestamp': '2020-08-09T10:38:05.055469'}
# 290 {'any': 'data290', 'timestamp': '2020-08-09T10:38:05.055471'}
# 291 {'any': 'data291', 'timestamp': '2020-08-09T10:38:05.055472'}
# 292 {'any': 'data292', 'timestamp': '2020-08-09T10:38:05.055473'}
# 293 {'any': 'data293', 'timestamp': '2020-08-09T10:38:05.055475'}
# 294 {'any': 'data294', 'timestamp': '2020-08-09T10:38:05.055476'}
# 295 {'any': 'data295', 'timestamp': '2020-08-09T10:38:05.055477'}
# 296 {'any': 'data296', 'timestamp': '2020-08-09T10:38:05.055479'}
# 297 {'any': 'data297', 'timestamp': '2020-08-09T10:38:05.055480'}
# 298 {'any': 'data298', 'timestamp': '2020-08-09T10:38:05.055481'}
# 299 {'any': 'data299', 'timestamp': '2020-08-09T10:38:05.055483'}
# 300 {'any': 'data300', 'timestamp': '2020-08-09T10:38:05.055486'}
# 301 {'any': 'data301', 'timestamp': '2020-08-09T10:38:05.055487'}
# 302 {'any': 'data302', 'timestamp': '2020-08-09T10:38:05.055491'}
# 303 {'any': 'data303', 'timestamp': '2020-08-09T10:38:05.055492'}
# 304 {'any': 'data304', 'timestamp': '2020-08-09T10:38:05.055493'}
# 305 {'any': 'data305', 'timestamp': '2020-08-09T10:38:05.055495'}
# 306 {'any': 'data306', 'timestamp': '2020-08-09T10:38:05.055496'}
# 307 {'any': 'data307', 'timestamp': '2020-08-09T10:38:05.055497'}
# 308 {'any': 'data308', 'timestamp': '2020-08-09T10:38:05.055499'}
# 309 {'any': 'data309', 'timestamp': '2020-08-09T10:38:05.055500'}
# 310 {'any': 'data310', 'timestamp': '2020-08-09T10:38:05.055502'}
# 311 {'any': 'data311', 'timestamp': '2020-08-09T10:38:05.055503'}
# 312 {'any': 'data312', 'timestamp': '2020-08-09T10:38:05.055506'}
# 313 {'any': 'data313', 'timestamp': '2020-08-09T10:38:05.055508'}
# 314 {'any': 'data314', 'timestamp': '2020-08-09T10:38:05.055509'}
# 315 {'any': 'data315', 'timestamp': '2020-08-09T10:38:05.055510'}
# 316 {'any': 'data316', 'timestamp': '2020-08-09T10:38:05.055512'}
# 317 {'any': 'data317', 'timestamp': '2020-08-09T10:38:05.055515'}
# 318 {'any': 'data318', 'timestamp': '2020-08-09T10:38:05.055516'}
# 319 {'any': 'data319', 'timestamp': '2020-08-09T10:38:05.055517'}
# 320 {'any': 'data320', 'timestamp': '2020-08-09T10:38:05.055519'}
# 321 {'any': 'data321', 'timestamp': '2020-08-09T10:38:05.055520'}
# 322 {'any': 'data322', 'timestamp': '2020-08-09T10:38:05.055521'}
# 323 {'any': 'data323', 'timestamp': '2020-08-09T10:38:05.055523'}
# 324 {'any': 'data324', 'timestamp': '2020-08-09T10:38:05.055526'}
# 325 {'any': 'data325', 'timestamp': '2020-08-09T10:38:05.055527'}
# 326 {'any': 'data326', 'timestamp': '2020-08-09T10:38:05.055528'}
# 327 {'any': 'data327', 'timestamp': '2020-08-09T10:38:05.055530'}
# 328 {'any': 'data328', 'timestamp': '2020-08-09T10:38:05.055531'}
# 329 {'any': 'data329', 'timestamp': '2020-08-09T10:38:05.055532'}
# 330 {'any': 'data330', 'timestamp': '2020-08-09T10:38:05.055534'}
# 331 {'any': 'data331', 'timestamp': '2020-08-09T10:38:05.055535'}
# 332 {'any': 'data332', 'timestamp': '2020-08-09T10:38:05.055536'}
# 333 {'any': 'data333', 'timestamp': '2020-08-09T10:38:05.055538'}
# 334 {'any': 'data334', 'timestamp': '2020-08-09T10:38:05.055539'}
# 335 {'any': 'data335', 'timestamp': '2020-08-09T10:38:05.055540'}
# 336 {'any': 'data336', 'timestamp': '2020-08-09T10:38:05.055544'}
# 337 {'any': 'data337', 'timestamp': '2020-08-09T10:38:05.055545'}
# 338 {'any': 'data338', 'timestamp': '2020-08-09T10:38:05.055547'}
# 339 {'any': 'data339', 'timestamp': '2020-08-09T10:38:05.055548'}
# 340 {'any': 'data340', 'timestamp': '2020-08-09T10:38:05.055549'}
# 341 {'any': 'data341', 'timestamp': '2020-08-09T10:38:05.055551'}
# 342 {'any': 'data342', 'timestamp': '2020-08-09T10:38:05.055552'}
# 343 {'any': 'data343', 'timestamp': '2020-08-09T10:38:05.055553'}
# 344 {'any': 'data344', 'timestamp': '2020-08-09T10:38:05.055555'}
# 345 {'any': 'data345', 'timestamp': '2020-08-09T10:38:05.055558'}
# 346 {'any': 'data346', 'timestamp': '2020-08-09T10:38:05.055559'}
# 347 {'any': 'data347', 'timestamp': '2020-08-09T10:38:05.055560'}
# 348 {'any': 'data348', 'timestamp': '2020-08-09T10:38:05.055563'}
# 349 {'any': 'data349', 'timestamp': '2020-08-09T10:38:05.055565'}
# 350 {'any': 'data350', 'timestamp': '2020-08-09T10:38:05.055566'}
# 351 {'any': 'data351', 'timestamp': '2020-08-09T10:38:05.055568'}
# 352 {'any': 'data352', 'timestamp': '2020-08-09T10:38:05.055569'}
# 353 {'any': 'data353', 'timestamp': '2020-08-09T10:38:05.055570'}
# 354 {'any': 'data354', 'timestamp': '2020-08-09T10:38:05.055573'}
# 355 {'any': 'data355', 'timestamp': '2020-08-09T10:38:05.055575'}
# 356 {'any': 'data356', 'timestamp': '2020-08-09T10:38:05.055576'}
# 357 {'any': 'data357', 'timestamp': '2020-08-09T10:38:05.055578'}
# 358 {'any': 'data358', 'timestamp': '2020-08-09T10:38:05.055579'}
# 359 {'any': 'data359', 'timestamp': '2020-08-09T10:38:05.055583'}
# 360 {'any': 'data360', 'timestamp': '2020-08-09T10:38:05.055586'}
# 361 {'any': 'data361', 'timestamp': '2020-08-09T10:38:05.055587'}
# 362 {'any': 'data362', 'timestamp': '2020-08-09T10:38:05.055589'}
# 363 {'any': 'data363', 'timestamp': '2020-08-09T10:38:05.055590'}
# 364 {'any': 'data364', 'timestamp': '2020-08-09T10:38:05.055591'}
# 365 {'any': 'data365', 'timestamp': '2020-08-09T10:38:05.055593'}
# 366 {'any': 'data366', 'timestamp': '2020-08-09T10:38:05.055594'}
# 367 {'any': 'data367', 'timestamp': '2020-08-09T10:38:05.055595'}
# 368 {'any': 'data368', 'timestamp': '2020-08-09T10:38:05.055597'}
# 369 {'any': 'data369', 'timestamp': '2020-08-09T10:38:05.055598'}
# 370 {'any': 'data370', 'timestamp': '2020-08-09T10:38:05.055599'}
# 371 {'any': 'data371', 'timestamp': '2020-08-09T10:38:05.055601'}
# 372 {'any': 'data372', 'timestamp': '2020-08-09T10:38:05.055604'}
# 373 {'any': 'data373', 'timestamp': '2020-08-09T10:38:05.055620'}
# 374 {'any': 'data374', 'timestamp': '2020-08-09T10:38:05.055621'}
# 375 {'any': 'data375', 'timestamp': '2020-08-09T10:38:05.055622'}
# 376 {'any': 'data376', 'timestamp': '2020-08-09T10:38:05.055624'}
# 377 {'any': 'data377', 'timestamp': '2020-08-09T10:38:05.055625'}
# 378 {'any': 'data378', 'timestamp': '2020-08-09T10:38:05.055626'}
# 379 {'any': 'data379', 'timestamp': '2020-08-09T10:38:05.055628'}
# 380 {'any': 'data380', 'timestamp': '2020-08-09T10:38:05.055629'}
# 381 {'any': 'data381', 'timestamp': '2020-08-09T10:38:05.055630'}
# 382 {'any': 'data382', 'timestamp': '2020-08-09T10:38:05.055632'}
# 383 {'any': 'data383', 'timestamp': '2020-08-09T10:38:05.055633'}
# 384 {'any': 'data384', 'timestamp': '2020-08-09T10:38:05.055637'}
# 385 {'any': 'data385', 'timestamp': '2020-08-09T10:38:05.055638'}
# 386 {'any': 'data386', 'timestamp': '2020-08-09T10:38:05.055640'}
# 387 {'any': 'data387', 'timestamp': '2020-08-09T10:38:05.055641'}
# 388 {'any': 'data388', 'timestamp': '2020-08-09T10:38:05.055642'}
# 389 {'any': 'data389', 'timestamp': '2020-08-09T10:38:05.055644'}
# 390 {'any': 'data390', 'timestamp': '2020-08-09T10:38:05.055645'}
# 391 {'any': 'data391', 'timestamp': '2020-08-09T10:38:05.055646'}
# 392 {'any': 'data392', 'timestamp': '2020-08-09T10:38:05.055648'}
# 393 {'any': 'data393', 'timestamp': '2020-08-09T10:38:05.055649'}
# 394 {'any': 'data394', 'timestamp': '2020-08-09T10:38:05.055650'}
# 395 {'any': 'data395', 'timestamp': '2020-08-09T10:38:05.055652'}
# 396 {'any': 'data396', 'timestamp': '2020-08-09T10:38:05.055655'}
# 397 {'any': 'data397', 'timestamp': '2020-08-09T10:38:05.055656'}
# 398 {'any': 'data398', 'timestamp': '2020-08-09T10:38:05.055658'}
# 399 {'any': 'data399', 'timestamp': '2020-08-09T10:38:05.055659'}
# 400 {'any': 'data400', 'timestamp': '2020-08-09T10:38:05.055660'}
# 401 {'any': 'data401', 'timestamp': '2020-08-09T10:38:05.055663'}
# 402 {'any': 'data402', 'timestamp': '2020-08-09T10:38:05.055665'}
# 403 {'any': 'data403', 'timestamp': '2020-08-09T10:38:05.055666'}
# 404 {'any': 'data404', 'timestamp': '2020-08-09T10:38:05.055667'}
# 405 {'any': 'data405', 'timestamp': '2020-08-09T10:38:05.055669'}
# 406 {'any': 'data406', 'timestamp': '2020-08-09T10:38:05.055670'}
# 407 {'any': 'data407', 'timestamp': '2020-08-09T10:38:05.055672'}
# 408 {'any': 'data408', 'timestamp': '2020-08-09T10:38:05.055675'}
# 409 {'any': 'data409', 'timestamp': '2020-08-09T10:38:05.055676'}
# 410 {'any': 'data410', 'timestamp': '2020-08-09T10:38:05.055678'}
# 411 {'any': 'data411', 'timestamp': '2020-08-09T10:38:05.055679'}
# 412 {'any': 'data412', 'timestamp': '2020-08-09T10:38:05.055680'}
# 413 {'any': 'data413', 'timestamp': '2020-08-09T10:38:05.055682'}
# 414 {'any': 'data414', 'timestamp': '2020-08-09T10:38:05.055683'}
# 415 {'any': 'data415', 'timestamp': '2020-08-09T10:38:05.055684'}
# 416 {'any': 'data416', 'timestamp': '2020-08-09T10:38:05.055686'}
# 417 {'any': 'data417', 'timestamp': '2020-08-09T10:38:05.055687'}
# 418 {'any': 'data418', 'timestamp': '2020-08-09T10:38:05.055688'}
# 419 {'any': 'data419', 'timestamp': '2020-08-09T10:38:05.055690'}
# 420 {'any': 'data420', 'timestamp': '2020-08-09T10:38:05.055693'}
# 421 {'any': 'data421', 'timestamp': '2020-08-09T10:38:05.055695'}
# 422 {'any': 'data422', 'timestamp': '2020-08-09T10:38:05.055696'}
# 423 {'any': 'data423', 'timestamp': '2020-08-09T10:38:05.055697'}
# 424 {'any': 'data424', 'timestamp': '2020-08-09T10:38:05.055699'}
# 425 {'any': 'data425', 'timestamp': '2020-08-09T10:38:05.055700'}
# 426 {'any': 'data426', 'timestamp': '2020-08-09T10:38:05.055701'}
# 427 {'any': 'data427', 'timestamp': '2020-08-09T10:38:05.055703'}
# 428 {'any': 'data428', 'timestamp': '2020-08-09T10:38:05.055706'}
# 429 {'any': 'data429', 'timestamp': '2020-08-09T10:38:05.055709'}
# 430 {'any': 'data430', 'timestamp': '2020-08-09T10:38:05.055710'}
# 431 {'any': 'data431', 'timestamp': '2020-08-09T10:38:05.055713'}
# 432 {'any': 'data432', 'timestamp': '2020-08-09T10:38:05.055717'}
# 433 {'any': 'data433', 'timestamp': '2020-08-09T10:38:05.055718'}
# 434 {'any': 'data434', 'timestamp': '2020-08-09T10:38:05.055720'}
# 435 {'any': 'data435', 'timestamp': '2020-08-09T10:38:05.055721'}
# 436 {'any': 'data436', 'timestamp': '2020-08-09T10:38:05.055723'}
# 437 {'any': 'data437', 'timestamp': '2020-08-09T10:38:05.055724'}
# 438 {'any': 'data438', 'timestamp': '2020-08-09T10:38:05.055725'}
# 439 {'any': 'data439', 'timestamp': '2020-08-09T10:38:05.055727'}
# 440 {'any': 'data440', 'timestamp': '2020-08-09T10:38:05.055728'}
# 441 {'any': 'data441', 'timestamp': '2020-08-09T10:38:05.055729'}
# 442 {'any': 'data442', 'timestamp': '2020-08-09T10:38:05.055731'}
# 443 {'any': 'data443', 'timestamp': '2020-08-09T10:38:05.055732'}
# 444 {'any': 'data444', 'timestamp': '2020-08-09T10:38:05.055735'}
# 445 {'any': 'data445', 'timestamp': '2020-08-09T10:38:05.055736'}
# 446 {'any': 'data446', 'timestamp': '2020-08-09T10:38:05.055738'}
# 447 {'any': 'data447', 'timestamp': '2020-08-09T10:38:05.055739'}
# 448 {'any': 'data448', 'timestamp': '2020-08-09T10:38:05.055740'}
# 449 {'any': 'data449', 'timestamp': '2020-08-09T10:38:05.055742'}
# 450 {'any': 'data450', 'timestamp': '2020-08-09T10:38:05.055743'}
# 451 {'any': 'data451', 'timestamp': '2020-08-09T10:38:05.055744'}
# 452 {'any': 'data452', 'timestamp': '2020-08-09T10:38:05.055746'}
# 453 {'any': 'data453', 'timestamp': '2020-08-09T10:38:05.055747'}
# 454 {'any': 'data454', 'timestamp': '2020-08-09T10:38:05.055748'}
# 455 {'any': 'data455', 'timestamp': '2020-08-09T10:38:05.055752'}
# 456 {'any': 'data456', 'timestamp': '2020-08-09T10:38:05.055755'}
# 457 {'any': 'data457', 'timestamp': '2020-08-09T10:38:05.055758'}
# 458 {'any': 'data458', 'timestamp': '2020-08-09T10:38:05.055760'}
# 459 {'any': 'data459', 'timestamp': '2020-08-09T10:38:05.055761'}
# 460 {'any': 'data460', 'timestamp': '2020-08-09T10:38:05.055763'}
# 461 {'any': 'data461', 'timestamp': '2020-08-09T10:38:05.055764'}
# 462 {'any': 'data462', 'timestamp': '2020-08-09T10:38:05.055765'}
# 463 {'any': 'data463', 'timestamp': '2020-08-09T10:38:05.055767'}
# 464 {'any': 'data464', 'timestamp': '2020-08-09T10:38:05.055768'}
# 465 {'any': 'data465', 'timestamp': '2020-08-09T10:38:05.055769'}
# 466 {'any': 'data466', 'timestamp': '2020-08-09T10:38:05.055771'}
# 467 {'any': 'data467', 'timestamp': '2020-08-09T10:38:05.055772'}
# 468 {'any': 'data468', 'timestamp': '2020-08-09T10:38:05.055775'}
# 469 {'any': 'data469', 'timestamp': '2020-08-09T10:38:05.055777'}
# 470 {'any': 'data470', 'timestamp': '2020-08-09T10:38:05.055778'}
# 471 {'any': 'data471', 'timestamp': '2020-08-09T10:38:05.055779'}
# 472 {'any': 'data472', 'timestamp': '2020-08-09T10:38:05.055781'}
# 473 {'any': 'data473', 'timestamp': '2020-08-09T10:38:05.055782'}
# 474 {'any': 'data474', 'timestamp': '2020-08-09T10:38:05.055783'}
# 475 {'any': 'data475', 'timestamp': '2020-08-09T10:38:05.055785'}
# 476 {'any': 'data476', 'timestamp': '2020-08-09T10:38:05.055786'}
# 477 {'any': 'data477', 'timestamp': '2020-08-09T10:38:05.055787'}
# 478 {'any': 'data478', 'timestamp': '2020-08-09T10:38:05.055789'}
# 479 {'any': 'data479', 'timestamp': '2020-08-09T10:38:05.055790'}
# 480 {'any': 'data480', 'timestamp': '2020-08-09T10:38:05.055793'}
# 481 {'any': 'data481', 'timestamp': '2020-08-09T10:38:05.055795'}
# 482 {'any': 'data482', 'timestamp': '2020-08-09T10:38:05.055796'}
# 483 {'any': 'data483', 'timestamp': '2020-08-09T10:38:05.055797'}
# 484 {'any': 'data484', 'timestamp': '2020-08-09T10:38:05.055799'}
# 485 {'any': 'data485', 'timestamp': '2020-08-09T10:38:05.055802'}
# 486 {'any': 'data486', 'timestamp': '2020-08-09T10:38:05.055803'}
# 487 {'any': 'data487', 'timestamp': '2020-08-09T10:38:05.055805'}
# 488 {'any': 'data488', 'timestamp': '2020-08-09T10:38:05.055806'}
# 489 {'any': 'data489', 'timestamp': '2020-08-09T10:38:05.055807'}
# 490 {'any': 'data490', 'timestamp': '2020-08-09T10:38:05.055809'}
# 491 {'any': 'data491', 'timestamp': '2020-08-09T10:38:05.055810'}
# 492 {'any': 'data492', 'timestamp': '2020-08-09T10:38:05.055814'}
# 493 {'any': 'data493', 'timestamp': '2020-08-09T10:38:05.055815'}
# 494 {'any': 'data494', 'timestamp': '2020-08-09T10:38:05.055816'}
# 495 {'any': 'data495', 'timestamp': '2020-08-09T10:38:05.055818'}
# 496 {'any': 'data496', 'timestamp': '2020-08-09T10:38:05.055819'}
# 497 {'any': 'data497', 'timestamp': '2020-08-09T10:38:05.055821'}
# 498 {'any': 'data498', 'timestamp': '2020-08-09T10:38:05.055822'}
# 499 {'any': 'data499', 'timestamp': '2020-08-09T10:38:05.055823'}
# 500 {'any': 'data500', 'timestamp': '2020-08-09T10:38:05.055825'}
# 501 {'any': 'data501', 'timestamp': '2020-08-09T10:38:05.055826'}
# 502 {'any': 'data502', 'timestamp': '2020-08-09T10:38:05.055827'}
# 503 {'any': 'data503', 'timestamp': '2020-08-09T10:38:05.055830'}
# 504 {'any': 'data504', 'timestamp': '2020-08-09T10:38:05.055833'}
# 505 {'any': 'data505', 'timestamp': '2020-08-09T10:38:05.055835'}
# 506 {'any': 'data506', 'timestamp': '2020-08-09T10:38:05.055836'}
# 507 {'any': 'data507', 'timestamp': '2020-08-09T10:38:05.055838'}
# 508 {'any': 'data508', 'timestamp': '2020-08-09T10:38:05.055839'}
# 509 {'any': 'data509', 'timestamp': '2020-08-09T10:38:05.055840'}
# 510 {'any': 'data510', 'timestamp': '2020-08-09T10:38:05.055842'}
# 511 {'any': 'data511', 'timestamp': '2020-08-09T10:38:05.055843'}
# 512 {'any': 'data512', 'timestamp': '2020-08-09T10:38:05.055844'}
# 513 {'any': 'data513', 'timestamp': '2020-08-09T10:38:05.055847'}
# 514 {'any': 'data514', 'timestamp': '2020-08-09T10:38:05.055867'}
# 515 {'any': 'data515', 'timestamp': '2020-08-09T10:38:05.055869'}
# 516 {'any': 'data516', 'timestamp': '2020-08-09T10:38:05.055872'}
# 517 {'any': 'data517', 'timestamp': '2020-08-09T10:38:05.055874'}
# 518 {'any': 'data518', 'timestamp': '2020-08-09T10:38:05.055875'}
# 519 {'any': 'data519', 'timestamp': '2020-08-09T10:38:05.055877'}
# 520 {'any': 'data520', 'timestamp': '2020-08-09T10:38:05.055878'}
# 521 {'any': 'data521', 'timestamp': '2020-08-09T10:38:05.055879'}
# 522 {'any': 'data522', 'timestamp': '2020-08-09T10:38:05.055881'}
# 523 {'any': 'data523', 'timestamp': '2020-08-09T10:38:05.055882'}
# 524 {'any': 'data524', 'timestamp': '2020-08-09T10:38:05.055883'}
# 525 {'any': 'data525', 'timestamp': '2020-08-09T10:38:05.055885'}
# 526 {'any': 'data526', 'timestamp': '2020-08-09T10:38:05.055886'}
# 527 {'any': 'data527', 'timestamp': '2020-08-09T10:38:05.055888'}
# 528 {'any': 'data528', 'timestamp': '2020-08-09T10:38:05.055892'}
# 529 {'any': 'data529', 'timestamp': '2020-08-09T10:38:05.055893'}
# 530 {'any': 'data530', 'timestamp': '2020-08-09T10:38:05.055894'}
# 531 {'any': 'data531', 'timestamp': '2020-08-09T10:38:05.055896'}
# 532 {'any': 'data532', 'timestamp': '2020-08-09T10:38:05.055897'}
# 533 {'any': 'data533', 'timestamp': '2020-08-09T10:38:05.055898'}
# 534 {'any': 'data534', 'timestamp': '2020-08-09T10:38:05.055900'}
# 535 {'any': 'data535', 'timestamp': '2020-08-09T10:38:05.055901'}
# 536 {'any': 'data536', 'timestamp': '2020-08-09T10:38:05.055903'}
# 537 {'any': 'data537', 'timestamp': '2020-08-09T10:38:05.055904'}
# 538 {'any': 'data538', 'timestamp': '2020-08-09T10:38:05.055905'}
# 539 {'any': 'data539', 'timestamp': '2020-08-09T10:38:05.055907'}
# 540 {'any': 'data540', 'timestamp': '2020-08-09T10:38:05.055910'}
# 541 {'any': 'data541', 'timestamp': '2020-08-09T10:38:05.055913'}
# 542 {'any': 'data542', 'timestamp': '2020-08-09T10:38:05.055914'}
# 543 {'any': 'data543', 'timestamp': '2020-08-09T10:38:05.055915'}
# 544 {'any': 'data544', 'timestamp': '2020-08-09T10:38:05.055917'}
# 545 {'any': 'data545', 'timestamp': '2020-08-09T10:38:05.055918'}
# 546 {'any': 'data546', 'timestamp': '2020-08-09T10:38:05.055920'}
# 547 {'any': 'data547', 'timestamp': '2020-08-09T10:38:05.055921'}
# 548 {'any': 'data548', 'timestamp': '2020-08-09T10:38:05.055922'}
# 549 {'any': 'data549', 'timestamp': '2020-08-09T10:38:05.055924'}
# 550 {'any': 'data550', 'timestamp': '2020-08-09T10:38:05.055925'}
# 551 {'any': 'data551', 'timestamp': '2020-08-09T10:38:05.055926'}
# 552 {'any': 'data552', 'timestamp': '2020-08-09T10:38:05.055930'}
# 553 {'any': 'data553', 'timestamp': '2020-08-09T10:38:05.055931'}
# 554 {'any': 'data554', 'timestamp': '2020-08-09T10:38:05.055934'}
# 555 {'any': 'data555', 'timestamp': '2020-08-09T10:38:05.055936'}
# 556 {'any': 'data556', 'timestamp': '2020-08-09T10:38:05.055939'}
# 557 {'any': 'data557', 'timestamp': '2020-08-09T10:38:05.055940'}
# 558 {'any': 'data558', 'timestamp': '2020-08-09T10:38:05.055941'}
# 559 {'any': 'data559', 'timestamp': '2020-08-09T10:38:05.055943'}
# 560 {'any': 'data560', 'timestamp': '2020-08-09T10:38:05.055944'}
# 561 {'any': 'data561', 'timestamp': '2020-08-09T10:38:05.055945'}
# 562 {'any': 'data562', 'timestamp': '2020-08-09T10:38:05.055947'}
# 563 {'any': 'data563', 'timestamp': '2020-08-09T10:38:05.055948'}
# 564 {'any': 'data564', 'timestamp': '2020-08-09T10:38:05.055951'}
# 565 {'any': 'data565', 'timestamp': '2020-08-09T10:38:05.055953'}
# 566 {'any': 'data566', 'timestamp': '2020-08-09T10:38:05.055954'}
# 567 {'any': 'data567', 'timestamp': '2020-08-09T10:38:05.055955'}
# 568 {'any': 'data568', 'timestamp': '2020-08-09T10:38:05.055957'}
# 569 {'any': 'data569', 'timestamp': '2020-08-09T10:38:05.055966'}
# 570 {'any': 'data570', 'timestamp': '2020-08-09T10:38:05.055968'}
# 571 {'any': 'data571', 'timestamp': '2020-08-09T10:38:05.055969'}
# 572 {'any': 'data572', 'timestamp': '2020-08-09T10:38:05.055970'}
# 573 {'any': 'data573', 'timestamp': '2020-08-09T10:38:05.055972'}
# 574 {'any': 'data574', 'timestamp': '2020-08-09T10:38:05.055973'}
# 575 {'any': 'data575', 'timestamp': '2020-08-09T10:38:05.055976'}
# 576 {'any': 'data576', 'timestamp': '2020-08-09T10:38:05.055979'}
# 577 {'any': 'data577', 'timestamp': '2020-08-09T10:38:05.055981'}
# 578 {'any': 'data578', 'timestamp': '2020-08-09T10:38:05.055982'}
# 579 {'any': 'data579', 'timestamp': '2020-08-09T10:38:05.055983'}
# 580 {'any': 'data580', 'timestamp': '2020-08-09T10:38:05.055985'}
# 581 {'any': 'data581', 'timestamp': '2020-08-09T10:38:05.055986'}
# 582 {'any': 'data582', 'timestamp': '2020-08-09T10:38:05.055988'}
# 583 {'any': 'data583', 'timestamp': '2020-08-09T10:38:05.055989'}
# 584 {'any': 'data584', 'timestamp': '2020-08-09T10:38:05.055990'}
# 585 {'any': 'data585', 'timestamp': '2020-08-09T10:38:05.055992'}
# 586 {'any': 'data586', 'timestamp': '2020-08-09T10:38:05.055993'}
# 587 {'any': 'data587', 'timestamp': '2020-08-09T10:38:05.055994'}
# 588 {'any': 'data588', 'timestamp': '2020-08-09T10:38:05.055997'}
# 589 {'any': 'data589', 'timestamp': '2020-08-09T10:38:05.055999'}
# 590 {'any': 'data590', 'timestamp': '2020-08-09T10:38:05.056000'}
# 591 {'any': 'data591', 'timestamp': '2020-08-09T10:38:05.056002'}
# 592 {'any': 'data592', 'timestamp': '2020-08-09T10:38:05.056003'}
# 593 {'any': 'data593', 'timestamp': '2020-08-09T10:38:05.056004'}
# 594 {'any': 'data594', 'timestamp': '2020-08-09T10:38:05.056006'}
# 595 {'any': 'data595', 'timestamp': '2020-08-09T10:38:05.056007'}
# 596 {'any': 'data596', 'timestamp': '2020-08-09T10:38:05.056008'}
# 597 {'any': 'data597', 'timestamp': '2020-08-09T10:38:05.056012'}
# 598 {'any': 'data598', 'timestamp': '2020-08-09T10:38:05.056013'}
# 599 {'any': 'data599', 'timestamp': '2020-08-09T10:38:05.056015'}
# 600 {'any': 'data600', 'timestamp': '2020-08-09T10:38:05.056018'}
# 601 {'any': 'data601', 'timestamp': '2020-08-09T10:38:05.056019'}
# 602 {'any': 'data602', 'timestamp': '2020-08-09T10:38:05.056021'}
# 603 {'any': 'data603', 'timestamp': '2020-08-09T10:38:05.056022'}
# 604 {'any': 'data604', 'timestamp': '2020-08-09T10:38:05.056023'}
# 605 {'any': 'data605', 'timestamp': '2020-08-09T10:38:05.056025'}
# 606 {'any': 'data606', 'timestamp': '2020-08-09T10:38:05.056026'}
# 607 {'any': 'data607', 'timestamp': '2020-08-09T10:38:05.056027'}
# 608 {'any': 'data608', 'timestamp': '2020-08-09T10:38:05.056029'}
# 609 {'any': 'data609', 'timestamp': '2020-08-09T10:38:05.056030'}
# 610 {'any': 'data610', 'timestamp': '2020-08-09T10:38:05.056031'}
# 611 {'any': 'data611', 'timestamp': '2020-08-09T10:38:05.056033'}
# 612 {'any': 'data612', 'timestamp': '2020-08-09T10:38:05.056036'}
# 613 {'any': 'data613', 'timestamp': '2020-08-09T10:38:05.056037'}
# 614 {'any': 'data614', 'timestamp': '2020-08-09T10:38:05.056039'}
# 615 {'any': 'data615', 'timestamp': '2020-08-09T10:38:05.056040'}
# 616 {'any': 'data616', 'timestamp': '2020-08-09T10:38:05.056041'}
# 617 {'any': 'data617', 'timestamp': '2020-08-09T10:38:05.056043'}
# 618 {'any': 'data618', 'timestamp': '2020-08-09T10:38:05.056044'}
# 619 {'any': 'data619', 'timestamp': '2020-08-09T10:38:05.056045'}
# 620 {'any': 'data620', 'timestamp': '2020-08-09T10:38:05.056047'}
# 621 {'any': 'data621', 'timestamp': '2020-08-09T10:38:05.056048'}
# 622 {'any': 'data622', 'timestamp': '2020-08-09T10:38:05.056049'}
# 623 {'any': 'data623', 'timestamp': '2020-08-09T10:38:05.056051'}
# 624 {'any': 'data624', 'timestamp': '2020-08-09T10:38:05.056054'}
# 625 {'any': 'data625', 'timestamp': '2020-08-09T10:38:05.056057'}
# 626 {'any': 'data626', 'timestamp': '2020-08-09T10:38:05.056059'}
# 627 {'any': 'data627', 'timestamp': '2020-08-09T10:38:05.056060'}
# 628 {'any': 'data628', 'timestamp': '2020-08-09T10:38:05.056061'}
# 629 {'any': 'data629', 'timestamp': '2020-08-09T10:38:05.056063'}
# 630 {'any': 'data630', 'timestamp': '2020-08-09T10:38:05.056064'}
# 631 {'any': 'data631', 'timestamp': '2020-08-09T10:38:05.056065'}
# 632 {'any': 'data632', 'timestamp': '2020-08-09T10:38:05.056067'}
# 633 {'any': 'data633', 'timestamp': '2020-08-09T10:38:05.056068'}
# 634 {'any': 'data634', 'timestamp': '2020-08-09T10:38:05.056069'}
# 635 {'any': 'data635', 'timestamp': '2020-08-09T10:38:05.056071'}
# 636 {'any': 'data636', 'timestamp': '2020-08-09T10:38:05.056074'}
# 637 {'any': 'data637', 'timestamp': '2020-08-09T10:38:05.056075'}
# 638 {'any': 'data638', 'timestamp': '2020-08-09T10:38:05.056077'}
# 639 {'any': 'data639', 'timestamp': '2020-08-09T10:38:05.056078'}
# 640 {'any': 'data640', 'timestamp': '2020-08-09T10:38:05.056079'}
# 641 {'any': 'data641', 'timestamp': '2020-08-09T10:38:05.056081'}
# 642 {'any': 'data642', 'timestamp': '2020-08-09T10:38:05.056082'}
# 643 {'any': 'data643', 'timestamp': '2020-08-09T10:38:05.056083'}
# 644 {'any': 'data644', 'timestamp': '2020-08-09T10:38:05.056085'}
# 645 {'any': 'data645', 'timestamp': '2020-08-09T10:38:05.056086'}
# 646 {'any': 'data646', 'timestamp': '2020-08-09T10:38:05.056087'}
# 647 {'any': 'data647', 'timestamp': '2020-08-09T10:38:05.056090'}
# 648 {'any': 'data648', 'timestamp': '2020-08-09T10:38:05.056094'}
# 649 {'any': 'data649', 'timestamp': '2020-08-09T10:38:05.056095'}
# 650 {'any': 'data650', 'timestamp': '2020-08-09T10:38:05.056096'}
# 651 {'any': 'data651', 'timestamp': '2020-08-09T10:38:05.056098'}
# 652 {'any': 'data652', 'timestamp': '2020-08-09T10:38:05.056099'}
# 653 {'any': 'data653', 'timestamp': '2020-08-09T10:38:05.056102'}
# 654 {'any': 'data654', 'timestamp': '2020-08-09T10:38:05.056104'}
# 655 {'any': 'data655', 'timestamp': '2020-08-09T10:38:05.056105'}
# 656 {'any': 'data656', 'timestamp': '2020-08-09T10:38:05.056107'}
# 657 {'any': 'data657', 'timestamp': '2020-08-09T10:38:05.056110'}
# 658 {'any': 'data658', 'timestamp': '2020-08-09T10:38:05.056111'}
# 659 {'any': 'data659', 'timestamp': '2020-08-09T10:38:05.056112'}
# 660 {'any': 'data660', 'timestamp': '2020-08-09T10:38:05.056116'}
# 661 {'any': 'data661', 'timestamp': '2020-08-09T10:38:05.056117'}
# 662 {'any': 'data662', 'timestamp': '2020-08-09T10:38:05.056118'}
# 663 {'any': 'data663', 'timestamp': '2020-08-09T10:38:05.056120'}
# 664 {'any': 'data664', 'timestamp': '2020-08-09T10:38:05.056121'}
# 665 {'any': 'data665', 'timestamp': '2020-08-09T10:38:05.056122'}
# 666 {'any': 'data666', 'timestamp': '2020-08-09T10:38:05.056124'}
# 667 {'any': 'data667', 'timestamp': '2020-08-09T10:38:05.056125'}
# 668 {'any': 'data668', 'timestamp': '2020-08-09T10:38:05.056127'}
# 669 {'any': 'data669', 'timestamp': '2020-08-09T10:38:05.056128'}
# 670 {'any': 'data670', 'timestamp': '2020-08-09T10:38:05.056129'}
# 671 {'any': 'data671', 'timestamp': '2020-08-09T10:38:05.056131'}
# 672 {'any': 'data672', 'timestamp': '2020-08-09T10:38:05.056134'}
# 673 {'any': 'data673', 'timestamp': '2020-08-09T10:38:05.056135'}
# 674 {'any': 'data674', 'timestamp': '2020-08-09T10:38:05.056136'}
# 675 {'any': 'data675', 'timestamp': '2020-08-09T10:38:05.056138'}
# 676 {'any': 'data676', 'timestamp': '2020-08-09T10:38:05.056139'}
# 677 {'any': 'data677', 'timestamp': '2020-08-09T10:38:05.056140'}
# 678 {'any': 'data678', 'timestamp': '2020-08-09T10:38:05.056142'}
# 679 {'any': 'data679', 'timestamp': '2020-08-09T10:38:05.056143'}
# 680 {'any': 'data680', 'timestamp': '2020-08-09T10:38:05.056147'}
# 681 {'any': 'data681', 'timestamp': '2020-08-09T10:38:05.056150'}
# 682 {'any': 'data682', 'timestamp': '2020-08-09T10:38:05.056152'}
# 683 {'any': 'data683', 'timestamp': '2020-08-09T10:38:05.056153'}
# 684 {'any': 'data684', 'timestamp': '2020-08-09T10:38:05.056156'}
# 685 {'any': 'data685', 'timestamp': '2020-08-09T10:38:05.056157'}
# 686 {'any': 'data686', 'timestamp': '2020-08-09T10:38:05.056159'}
# 687 {'any': 'data687', 'timestamp': '2020-08-09T10:38:05.056160'}
# 688 {'any': 'data688', 'timestamp': '2020-08-09T10:38:05.056161'}
# 689 {'any': 'data689', 'timestamp': '2020-08-09T10:38:05.056163'}
# 690 {'any': 'data690', 'timestamp': '2020-08-09T10:38:05.056164'}
# 691 {'any': 'data691', 'timestamp': '2020-08-09T10:38:05.056166'}
# 692 {'any': 'data692', 'timestamp': '2020-08-09T10:38:05.056167'}
# 693 {'any': 'data693', 'timestamp': '2020-08-09T10:38:05.056168'}
# 694 {'any': 'data694', 'timestamp': '2020-08-09T10:38:05.056170'}
# 695 {'any': 'data695', 'timestamp': '2020-08-09T10:38:05.056171'}
# 696 {'any': 'data696', 'timestamp': '2020-08-09T10:38:05.056174'}
# 697 {'any': 'data697', 'timestamp': '2020-08-09T10:38:05.056176'}
# 698 {'any': 'data698', 'timestamp': '2020-08-09T10:38:05.056177'}
# 699 {'any': 'data699', 'timestamp': '2020-08-09T10:38:05.056178'}
# 700 {'any': 'data700', 'timestamp': '2020-08-09T10:38:05.056180'}
# 701 {'any': 'data701', 'timestamp': '2020-08-09T10:38:05.056181'}
# 702 {'any': 'data702', 'timestamp': '2020-08-09T10:38:05.056182'}
# 703 {'any': 'data703', 'timestamp': '2020-08-09T10:38:05.056184'}
# 704 {'any': 'data704', 'timestamp': '2020-08-09T10:38:05.056185'}
# 705 {'any': 'data705', 'timestamp': '2020-08-09T10:38:05.056186'}
# 706 {'any': 'data706', 'timestamp': '2020-08-09T10:38:05.056188'}
# 707 {'any': 'data707', 'timestamp': '2020-08-09T10:38:05.056189'}
# 708 {'any': 'data708', 'timestamp': '2020-08-09T10:38:05.056193'}
# 709 {'any': 'data709', 'timestamp': '2020-08-09T10:38:05.056196'}
# 710 {'any': 'data710', 'timestamp': '2020-08-09T10:38:05.056197'}
# 711 {'any': 'data711', 'timestamp': '2020-08-09T10:38:05.056199'}
# 712 {'any': 'data712', 'timestamp': '2020-08-09T10:38:05.056200'}
# 713 {'any': 'data713', 'timestamp': '2020-08-09T10:38:05.056201'}
# 714 {'any': 'data714', 'timestamp': '2020-08-09T10:38:05.056203'}
# 715 {'any': 'data715', 'timestamp': '2020-08-09T10:38:05.056204'}
# 716 {'any': 'data716', 'timestamp': '2020-08-09T10:38:05.056205'}
# 717 {'any': 'data717', 'timestamp': '2020-08-09T10:38:05.056207'}
# 718 {'any': 'data718', 'timestamp': '2020-08-09T10:38:05.056208'}
# 719 {'any': 'data719', 'timestamp': '2020-08-09T10:38:05.056211'}
# 720 {'any': 'data720', 'timestamp': '2020-08-09T10:38:05.056214'}
# 721 {'any': 'data721', 'timestamp': '2020-08-09T10:38:05.056216'}
# 722 {'any': 'data722', 'timestamp': '2020-08-09T10:38:05.056217'}
# 723 {'any': 'data723', 'timestamp': '2020-08-09T10:38:05.056219'}
# 724 {'any': 'data724', 'timestamp': '2020-08-09T10:38:05.056220'}
# 725 {'any': 'data725', 'timestamp': '2020-08-09T10:38:05.056221'}
# 726 {'any': 'data726', 'timestamp': '2020-08-09T10:38:05.056223'}
# 727 {'any': 'data727', 'timestamp': '2020-08-09T10:38:05.056224'}
# 728 {'any': 'data728', 'timestamp': '2020-08-09T10:38:05.056225'}
# 729 {'any': 'data729', 'timestamp': '2020-08-09T10:38:05.056227'}
# 730 {'any': 'data730', 'timestamp': '2020-08-09T10:38:05.056228'}
# 731 {'any': 'data731', 'timestamp': '2020-08-09T10:38:05.056229'}
# 732 {'any': 'data732', 'timestamp': '2020-08-09T10:38:05.056233'}
# 733 {'any': 'data733', 'timestamp': '2020-08-09T10:38:05.056234'}
# 734 {'any': 'data734', 'timestamp': '2020-08-09T10:38:05.056236'}
# 735 {'any': 'data735', 'timestamp': '2020-08-09T10:38:05.056237'}
# 736 {'any': 'data736', 'timestamp': '2020-08-09T10:38:05.056238'}
# 737 {'any': 'data737', 'timestamp': '2020-08-09T10:38:05.056242'}
# 738 {'any': 'data738', 'timestamp': '2020-08-09T10:38:05.056243'}
# 739 {'any': 'data739', 'timestamp': '2020-08-09T10:38:05.056244'}
# 740 {'any': 'data740', 'timestamp': '2020-08-09T10:38:05.056246'}
# 741 {'any': 'data741', 'timestamp': '2020-08-09T10:38:05.056247'}
# 742 {'any': 'data742', 'timestamp': '2020-08-09T10:38:05.056248'}
# 743 {'any': 'data743', 'timestamp': '2020-08-09T10:38:05.056250'}
# 744 {'any': 'data744', 'timestamp': '2020-08-09T10:38:05.056253'}
# 745 {'any': 'data745', 'timestamp': '2020-08-09T10:38:05.056254'}
# 746 {'any': 'data746', 'timestamp': '2020-08-09T10:38:05.056256'}
# 747 {'any': 'data747', 'timestamp': '2020-08-09T10:38:05.056257'}
# 748 {'any': 'data748', 'timestamp': '2020-08-09T10:38:05.056258'}
# 749 {'any': 'data749', 'timestamp': '2020-08-09T10:38:05.056260'}
# 750 {'any': 'data750', 'timestamp': '2020-08-09T10:38:05.056261'}
# 751 {'any': 'data751', 'timestamp': '2020-08-09T10:38:05.056262'}
# 752 {'any': 'data752', 'timestamp': '2020-08-09T10:38:05.056264'}
# 753 {'any': 'data753', 'timestamp': '2020-08-09T10:38:05.056265'}
# 754 {'any': 'data754', 'timestamp': '2020-08-09T10:38:05.056266'}
# 755 {'any': 'data755', 'timestamp': '2020-08-09T10:38:05.056268'}
# 756 {'any': 'data756', 'timestamp': '2020-08-09T10:38:05.056271'}
# 757 {'any': 'data757', 'timestamp': '2020-08-09T10:38:05.056272'}
# 758 {'any': 'data758', 'timestamp': '2020-08-09T10:38:05.056276'}
# 759 {'any': 'data759', 'timestamp': '2020-08-09T10:38:05.056277'}
# 760 {'any': 'data760', 'timestamp': '2020-08-09T10:38:05.056279'}
# 761 {'any': 'data761', 'timestamp': '2020-08-09T10:38:05.056280'}
# 762 {'any': 'data762', 'timestamp': '2020-08-09T10:38:05.056282'}
# 763 {'any': 'data763', 'timestamp': '2020-08-09T10:38:05.056283'}
# 764 {'any': 'data764', 'timestamp': '2020-08-09T10:38:05.056284'}
# 765 {'any': 'data765', 'timestamp': '2020-08-09T10:38:05.056287'}
# 766 {'any': 'data766', 'timestamp': '2020-08-09T10:38:05.056289'}
# 767 {'any': 'data767', 'timestamp': '2020-08-09T10:38:05.056290'}
# 768 {'any': 'data768', 'timestamp': '2020-08-09T10:38:05.056293'}
# 769 {'any': 'data769', 'timestamp': '2020-08-09T10:38:05.056295'}
# 770 {'any': 'data770', 'timestamp': '2020-08-09T10:38:05.056296'}
# 771 {'any': 'data771', 'timestamp': '2020-08-09T10:38:05.056297'}
# 772 {'any': 'data772', 'timestamp': '2020-08-09T10:38:05.056299'}
# 773 {'any': 'data773', 'timestamp': '2020-08-09T10:38:05.056300'}
# 774 {'any': 'data774', 'timestamp': '2020-08-09T10:38:05.056302'}
# 775 {'any': 'data775', 'timestamp': '2020-08-09T10:38:05.056303'}
# 776 {'any': 'data776', 'timestamp': '2020-08-09T10:38:05.056304'}
# 777 {'any': 'data777', 'timestamp': '2020-08-09T10:38:05.056306'}
# 778 {'any': 'data778', 'timestamp': '2020-08-09T10:38:05.056307'}
# 779 {'any': 'data779', 'timestamp': '2020-08-09T10:38:05.056308'}
# 780 {'any': 'data780', 'timestamp': '2020-08-09T10:38:05.056311'}
# 781 {'any': 'data781', 'timestamp': '2020-08-09T10:38:05.056313'}
# 782 {'any': 'data782', 'timestamp': '2020-08-09T10:38:05.056314'}
# 783 {'any': 'data783', 'timestamp': '2020-08-09T10:38:05.056316'}
# 784 {'any': 'data784', 'timestamp': '2020-08-09T10:38:05.056317'}
# 785 {'any': 'data785', 'timestamp': '2020-08-09T10:38:05.056318'}
# 786 {'any': 'data786', 'timestamp': '2020-08-09T10:38:05.056320'}
# 787 {'any': 'data787', 'timestamp': '2020-08-09T10:38:05.056321'}
# 788 {'any': 'data788', 'timestamp': '2020-08-09T10:38:05.056322'}
# 789 {'any': 'data789', 'timestamp': '2020-08-09T10:38:05.056324'}
# 790 {'any': 'data790', 'timestamp': '2020-08-09T10:38:05.056325'}
# 791 {'any': 'data791', 'timestamp': '2020-08-09T10:38:05.056329'}
# 792 {'any': 'data792', 'timestamp': '2020-08-09T10:38:05.056332'}
# 793 {'any': 'data793', 'timestamp': '2020-08-09T10:38:05.056335'}
# 794 {'any': 'data794', 'timestamp': '2020-08-09T10:38:05.056337'}
# 795 {'any': 'data795', 'timestamp': '2020-08-09T10:38:05.056338'}
# 796 {'any': 'data796', 'timestamp': '2020-08-09T10:38:05.056339'}
# 797 {'any': 'data797', 'timestamp': '2020-08-09T10:38:05.056341'}
# 798 {'any': 'data798', 'timestamp': '2020-08-09T10:38:05.056342'}
# 799 {'any': 'data799', 'timestamp': '2020-08-09T10:38:05.056343'}
# 800 {'any': 'data800', 'timestamp': '2020-08-09T10:38:05.056345'}
# 801 {'any': 'data801', 'timestamp': '2020-08-09T10:38:05.056346'}
# 802 {'any': 'data802', 'timestamp': '2020-08-09T10:38:05.056347'}
# 803 {'any': 'data803', 'timestamp': '2020-08-09T10:38:05.056349'}
# 804 {'any': 'data804', 'timestamp': '2020-08-09T10:38:05.056359'}
# 805 {'any': 'data805', 'timestamp': '2020-08-09T10:38:05.056360'}
# 806 {'any': 'data806', 'timestamp': '2020-08-09T10:38:05.056364'}
# 807 {'any': 'data807', 'timestamp': '2020-08-09T10:38:05.056365'}
# 808 {'any': 'data808', 'timestamp': '2020-08-09T10:38:05.056366'}
# 809 {'any': 'data809', 'timestamp': '2020-08-09T10:38:05.056368'}
# 810 {'any': 'data810', 'timestamp': '2020-08-09T10:38:05.056369'}
# 811 {'any': 'data811', 'timestamp': '2020-08-09T10:38:05.056371'}
# 812 {'any': 'data812', 'timestamp': '2020-08-09T10:38:05.056372'}
# 813 {'any': 'data813', 'timestamp': '2020-08-09T10:38:05.056373'}
# 814 {'any': 'data814', 'timestamp': '2020-08-09T10:38:05.056375'}
# 815 {'any': 'data815', 'timestamp': '2020-08-09T10:38:05.056376'}
# 816 {'any': 'data816', 'timestamp': '2020-08-09T10:38:05.056379'}
# 817 {'any': 'data817', 'timestamp': '2020-08-09T10:38:05.056380'}
# 818 {'any': 'data818', 'timestamp': '2020-08-09T10:38:05.056382'}
# 819 {'any': 'data819', 'timestamp': '2020-08-09T10:38:05.056383'}
# 820 {'any': 'data820', 'timestamp': '2020-08-09T10:38:05.056384'}
# 821 {'any': 'data821', 'timestamp': '2020-08-09T10:38:05.056387'}
# ...
# 9859 {'any': 'data9859', 'timestamp': '2020-08-09T10:38:05.073123'}
# 9860 {'any': 'data9860', 'timestamp': '2020-08-09T10:38:05.073124'}
# 9861 {'any': 'data9861', 'timestamp': '2020-08-09T10:38:05.073127'}
# 9862 {'any': 'data9862', 'timestamp': '2020-08-09T10:38:05.073130'}
# 9863 {'any': 'data9863', 'timestamp': '2020-08-09T10:38:05.073131'}
# 9864 {'any': 'data9864', 'timestamp': '2020-08-09T10:38:05.073132'}
# 9865 {'any': 'data9865', 'timestamp': '2020-08-09T10:38:05.073133'}
# 9866 {'any': 'data9866', 'timestamp': '2020-08-09T10:38:05.073134'}
# 9867 {'any': 'data9867', 'timestamp': '2020-08-09T10:38:05.073135'}
# 9868 {'any': 'data9868', 'timestamp': '2020-08-09T10:38:05.073137'}
# 9869 {'any': 'data9869', 'timestamp': '2020-08-09T10:38:05.073138'}
# 9870 {'any': 'data9870', 'timestamp': '2020-08-09T10:38:05.073139'}
# 9871 {'any': 'data9871', 'timestamp': '2020-08-09T10:38:05.073140'}
# 9872 {'any': 'data9872', 'timestamp': '2020-08-09T10:38:05.073141'}
# 9873 {'any': 'data9873', 'timestamp': '2020-08-09T10:38:05.073144'}
# 9874 {'any': 'data9874', 'timestamp': '2020-08-09T10:38:05.073145'}
# 9875 {'any': 'data9875', 'timestamp': '2020-08-09T10:38:05.073147'}
# 9876 {'any': 'data9876', 'timestamp': '2020-08-09T10:38:05.073148'}
# 9877 {'any': 'data9877', 'timestamp': '2020-08-09T10:38:05.073151'}
# 9878 {'any': 'data9878', 'timestamp': '2020-08-09T10:38:05.073152'}
# 9879 {'any': 'data9879', 'timestamp': '2020-08-09T10:38:05.073153'}
# 9880 {'any': 'data9880', 'timestamp': '2020-08-09T10:38:05.073155'}
# 9881 {'any': 'data9881', 'timestamp': '2020-08-09T10:38:05.073156'}
# 9882 {'any': 'data9882', 'timestamp': '2020-08-09T10:38:05.073157'}
# 9883 {'any': 'data9883', 'timestamp': '2020-08-09T10:38:05.073158'}
# 9884 {'any': 'data9884', 'timestamp': '2020-08-09T10:38:05.073159'}
# 9885 {'any': 'data9885', 'timestamp': '2020-08-09T10:38:05.073162'}
# 9886 {'any': 'data9886', 'timestamp': '2020-08-09T10:38:05.073163'}
# 9887 {'any': 'data9887', 'timestamp': '2020-08-09T10:38:05.073164'}
# 9888 {'any': 'data9888', 'timestamp': '2020-08-09T10:38:05.073166'}
# 9889 {'any': 'data9889', 'timestamp': '2020-08-09T10:38:05.073167'}
# 9890 {'any': 'data9890', 'timestamp': '2020-08-09T10:38:05.073170'}
# 9891 {'any': 'data9891', 'timestamp': '2020-08-09T10:38:05.073171'}
# 9892 {'any': 'data9892', 'timestamp': '2020-08-09T10:38:05.073172'}
# 9893 {'any': 'data9893', 'timestamp': '2020-08-09T10:38:05.073173'}
# 9894 {'any': 'data9894', 'timestamp': '2020-08-09T10:38:05.073174'}
# 9895 {'any': 'data9895', 'timestamp': '2020-08-09T10:38:05.073175'}
# 9896 {'any': 'data9896', 'timestamp': '2020-08-09T10:38:05.073177'}
# 9897 {'any': 'data9897', 'timestamp': '2020-08-09T10:38:05.073179'}
# 9898 {'any': 'data9898', 'timestamp': '2020-08-09T10:38:05.073181'}
# 9899 {'any': 'data9899', 'timestamp': '2020-08-09T10:38:05.073182'}
# 9900 {'any': 'data9900', 'timestamp': '2020-08-09T10:38:05.073185'}
# 9901 {'any': 'data9901', 'timestamp': '2020-08-09T10:38:05.073186'}
# 9902 {'any': 'data9902', 'timestamp': '2020-08-09T10:38:05.073187'}
# 9903 {'any': 'data9903', 'timestamp': '2020-08-09T10:38:05.073189'}
# 9904 {'any': 'data9904', 'timestamp': '2020-08-09T10:38:05.073190'}
# 9905 {'any': 'data9905', 'timestamp': '2020-08-09T10:38:05.073191'}
# 9906 {'any': 'data9906', 'timestamp': '2020-08-09T10:38:05.073192'}
# 9907 {'any': 'data9907', 'timestamp': '2020-08-09T10:38:05.073193'}
# 9908 {'any': 'data9908', 'timestamp': '2020-08-09T10:38:05.073195'}
# 9909 {'any': 'data9909', 'timestamp': '2020-08-09T10:38:05.073197'}
# 9910 {'any': 'data9910', 'timestamp': '2020-08-09T10:38:05.073199'}
# 9911 {'any': 'data9911', 'timestamp': '2020-08-09T10:38:05.073200'}
# 9912 {'any': 'data9912', 'timestamp': '2020-08-09T10:38:05.073201'}
# 9913 {'any': 'data9913', 'timestamp': '2020-08-09T10:38:05.073202'}
# 9914 {'any': 'data9914', 'timestamp': '2020-08-09T10:38:05.073203'}
# 9915 {'any': 'data9915', 'timestamp': '2020-08-09T10:38:05.073204'}
# 9916 {'any': 'data9916', 'timestamp': '2020-08-09T10:38:05.073206'}
# 9917 {'any': 'data9917', 'timestamp': '2020-08-09T10:38:05.073207'}
# 9918 {'any': 'data9918', 'timestamp': '2020-08-09T10:38:05.073210'}
# 9919 {'any': 'data9919', 'timestamp': '2020-08-09T10:38:05.073211'}
# 9920 {'any': 'data9920', 'timestamp': '2020-08-09T10:38:05.073212'}
# 9921 {'any': 'data9921', 'timestamp': '2020-08-09T10:38:05.073215'}
# 9922 {'any': 'data9922', 'timestamp': '2020-08-09T10:38:05.073216'}
# 9923 {'any': 'data9923', 'timestamp': '2020-08-09T10:38:05.073217'}
# 9924 {'any': 'data9924', 'timestamp': '2020-08-09T10:38:05.073218'}
# 9925 {'any': 'data9925', 'timestamp': '2020-08-09T10:38:05.073219'}
# 9926 {'any': 'data9926', 'timestamp': '2020-08-09T10:38:05.073221'}
# 9927 {'any': 'data9927', 'timestamp': '2020-08-09T10:38:05.073222'}
# 9928 {'any': 'data9928', 'timestamp': '2020-08-09T10:38:05.073223'}
# 9929 {'any': 'data9929', 'timestamp': '2020-08-09T10:38:05.073224'}
# 9930 {'any': 'data9930', 'timestamp': '2020-08-09T10:38:05.073225'}
# 9931 {'any': 'data9931', 'timestamp': '2020-08-09T10:38:05.073227'}
# 9932 {'any': 'data9932', 'timestamp': '2020-08-09T10:38:05.073228'}
# 9933 {'any': 'data9933', 'timestamp': '2020-08-09T10:38:05.073231'}
# 9934 {'any': 'data9934', 'timestamp': '2020-08-09T10:38:05.073232'}
# 9935 {'any': 'data9935', 'timestamp': '2020-08-09T10:38:05.073233'}
# 9936 {'any': 'data9936', 'timestamp': '2020-08-09T10:38:05.073234'}
# 9937 {'any': 'data9937', 'timestamp': '2020-08-09T10:38:05.073236'}
# 9938 {'any': 'data9938', 'timestamp': '2020-08-09T10:38:05.073237'}
# 9939 {'any': 'data9939', 'timestamp': '2020-08-09T10:38:05.073238'}
# 9940 {'any': 'data9940', 'timestamp': '2020-08-09T10:38:05.073239'}
# 9941 {'any': 'data9941', 'timestamp': '2020-08-09T10:38:05.073240'}
# 9942 {'any': 'data9942', 'timestamp': '2020-08-09T10:38:05.073241'}
# 9943 {'any': 'data9943', 'timestamp': '2020-08-09T10:38:05.073243'}
# 9944 {'any': 'data9944', 'timestamp': '2020-08-09T10:38:05.073244'}
# 9945 {'any': 'data9945', 'timestamp': '2020-08-09T10:38:05.073246'}
# 9946 {'any': 'data9946', 'timestamp': '2020-08-09T10:38:05.073249'}
# 9947 {'any': 'data9947', 'timestamp': '2020-08-09T10:38:05.073250'}
# 9948 {'any': 'data9948', 'timestamp': '2020-08-09T10:38:05.073252'}
# 9949 {'any': 'data9949', 'timestamp': '2020-08-09T10:38:05.073253'}
# 9950 {'any': 'data9950', 'timestamp': '2020-08-09T10:38:05.073256'}
# 9951 {'any': 'data9951', 'timestamp': '2020-08-09T10:38:05.073257'}
# 9952 {'any': 'data9952', 'timestamp': '2020-08-09T10:38:05.073258'}
# 9953 {'any': 'data9953', 'timestamp': '2020-08-09T10:38:05.073259'}
# 9954 {'any': 'data9954', 'timestamp': '2020-08-09T10:38:05.073260'}
# 9955 {'any': 'data9955', 'timestamp': '2020-08-09T10:38:05.073261'}
# 9956 {'any': 'data9956', 'timestamp': '2020-08-09T10:38:05.073263'}
# 9957 {'any': 'data9957', 'timestamp': '2020-08-09T10:38:05.073266'}
# 9958 {'any': 'data9958', 'timestamp': '2020-08-09T10:38:05.073267'}
# 9959 {'any': 'data9959', 'timestamp': '2020-08-09T10:38:05.073268'}
# 9960 {'any': 'data9960', 'timestamp': '2020-08-09T10:38:05.073269'}
# 9961 {'any': 'data9961', 'timestamp': '2020-08-09T10:38:05.073270'}
# 9962 {'any': 'data9962', 'timestamp': '2020-08-09T10:38:05.073272'}
# 9963 {'any': 'data9963', 'timestamp': '2020-08-09T10:38:05.073274'}
# 9964 {'any': 'data9964', 'timestamp': '2020-08-09T10:38:05.073276'}
# 9965 {'any': 'data9965', 'timestamp': '2020-08-09T10:38:05.073277'}
# 9966 {'any': 'data9966', 'timestamp': '2020-08-09T10:38:05.073278'}
# 9967 {'any': 'data9967', 'timestamp': '2020-08-09T10:38:05.073279'}
# 9968 {'any': 'data9968', 'timestamp': '2020-08-09T10:38:05.073280'}
# 9969 {'any': 'data9969', 'timestamp': '2020-08-09T10:38:05.073283'}
# 9970 {'any': 'data9970', 'timestamp': '2020-08-09T10:38:05.073284'}
# 9971 {'any': 'data9971', 'timestamp': '2020-08-09T10:38:05.073285'}
# 9972 {'any': 'data9972', 'timestamp': '2020-08-09T10:38:05.073287'}
# 9973 {'any': 'data9973', 'timestamp': '2020-08-09T10:38:05.073304'}
# 9974 {'any': 'data9974', 'timestamp': '2020-08-09T10:38:05.073307'}
# 9975 {'any': 'data9975', 'timestamp': '2020-08-09T10:38:05.073308'}
# 9976 {'any': 'data9976', 'timestamp': '2020-08-09T10:38:05.073309'}
# 9977 {'any': 'data9977', 'timestamp': '2020-08-09T10:38:05.073311'}
# 9978 {'any': 'data9978', 'timestamp': '2020-08-09T10:38:05.073312'}
# 9979 {'any': 'data9979', 'timestamp': '2020-08-09T10:38:05.073313'}
# 9980 {'any': 'data9980', 'timestamp': '2020-08-09T10:38:05.073314'}
# 9981 {'any': 'data9981', 'timestamp': '2020-08-09T10:38:05.073322'}
# 9982 {'any': 'data9982', 'timestamp': '2020-08-09T10:38:05.073323'}
# 9983 {'any': 'data9983', 'timestamp': '2020-08-09T10:38:05.073324'}
# 9984 {'any': 'data9984', 'timestamp': '2020-08-09T10:38:05.073325'}
# 9985 {'any': 'data9985', 'timestamp': '2020-08-09T10:38:05.073326'}
# 9986 {'any': 'data9986', 'timestamp': '2020-08-09T10:38:05.073327'}
# 9987 {'any': 'data9987', 'timestamp': '2020-08-09T10:38:05.073329'}
# 9988 {'any': 'data9988', 'timestamp': '2020-08-09T10:38:05.073330'}
# 9989 {'any': 'data9989', 'timestamp': '2020-08-09T10:38:05.073331'}
# 9990 {'any': 'data9990', 'timestamp': '2020-08-09T10:38:05.073332'}
# 9991 {'any': 'data9991', 'timestamp': '2020-08-09T10:38:05.073333'}
# 9992 {'any': 'data9992', 'timestamp': '2020-08-09T10:38:05.073335'}
# 9993 {'any': 'data9993', 'timestamp': '2020-08-09T10:38:05.073337'}
# 9994 {'any': 'data9994', 'timestamp': '2020-08-09T10:38:05.073339'}
# 9995 {'any': 'data9995', 'timestamp': '2020-08-09T10:38:05.073340'}
# 9996 {'any': 'data9996', 'timestamp': '2020-08-09T10:38:05.073341'}
# 9997 {'any': 'data9997', 'timestamp': '2020-08-09T10:38:05.073342'}
# 9998 {'any': 'data9998', 'timestamp': '2020-08-09T10:38:05.073343'}
# 9999 {'any': 'data9999', 'timestamp': '2020-08-09T10:38:05.073344'}
# 0 {'any': 'data0', 'timestamp': '2020-08-09T10:38:06.144445'}
# 1 {'any': 'data1', 'timestamp': '2020-08-09T10:38:06.169020'}
# 2 {'any': 'data2', 'timestamp': '2020-08-09T10:38:06.200236'}
# 3 {'any': 'data3', 'timestamp': '2020-08-09T10:38:06.232717'}
# 4 {'any': 'data4', 'timestamp': '2020-08-09T10:38:06.267830'}
# 5 {'any': 'data5', 'timestamp': '2020-08-09T10:38:06.296401'}
# 6 {'any': 'data6', 'timestamp': '2020-08-09T10:38:06.326014'}
# 7 {'any': 'data7', 'timestamp': '2020-08-09T10:38:06.375076'}
# 8 {'any': 'data8', 'timestamp': '2020-08-09T10:38:06.407042'}
# 9 {'any': 'data9', 'timestamp': '2020-08-09T10:38:06.438367'}
# 10 {'any': 'data10', 'timestamp': '2020-08-09T10:38:06.470213'}
# 11 {'any': 'data11', 'timestamp': '2020-08-09T10:38:06.502252'}
# 12 {'any': 'data12', 'timestamp': '2020-08-09T10:38:06.535265'}
# 13 {'any': 'data13', 'timestamp': '2020-08-09T10:38:06.568750'}
# 14 {'any': 'data14', 'timestamp': '2020-08-09T10:38:06.600364'}
# 15 {'any': 'data15', 'timestamp': '2020-08-09T10:38:06.632548'}
# 16 {'any': 'data16', 'timestamp': '2020-08-09T10:38:06.666680'}
# 17 {'any': 'data17', 'timestamp': '2020-08-09T10:38:06.700812'}
# 18 {'any': 'data18', 'timestamp': '2020-08-09T10:38:06.739238'}
# 19 {'any': 'data19', 'timestamp': '2020-08-09T10:38:06.772155'}
# 20 {'any': 'data20', 'timestamp': '2020-08-09T10:38:06.804164'}
# 21 {'any': 'data21', 'timestamp': '2020-08-09T10:38:06.835879'}
# 22 {'any': 'data22', 'timestamp': '2020-08-09T10:38:06.868157'}
# 23 {'any': 'data23', 'timestamp': '2020-08-09T10:38:06.900443'}
# 24 {'any': 'data24', 'timestamp': '2020-08-09T10:38:06.929939'}
# 25 {'any': 'data25', 'timestamp': '2020-08-09T10:38:06.963064'}
# 26 {'any': 'data26', 'timestamp': '2020-08-09T10:38:06.996122'}
# 27 {'any': 'data27', 'timestamp': '2020-08-09T10:38:07.028301'}
# 28 {'any': 'data28', 'timestamp': '2020-08-09T10:38:07.059944'}
# 29 {'any': 'data29', 'timestamp': '2020-08-09T10:38:07.099598'}
# 30 {'any': 'data30', 'timestamp': '2020-08-09T10:38:07.139222'}
# 31 {'any': 'data31', 'timestamp': '2020-08-09T10:38:07.171197'}
# 32 {'any': 'data32', 'timestamp': '2020-08-09T10:38:07.220210'}
# 33 {'any': 'data33', 'timestamp': '2020-08-09T10:38:07.251389'}
# 34 {'any': 'data34', 'timestamp': '2020-08-09T10:38:07.284267'}
# 35 {'any': 'data35', 'timestamp': '2020-08-09T10:38:07.316021'}
# 36 {'any': 'data36', 'timestamp': '2020-08-09T10:38:07.347296'}
# 37 {'any': 'data37', 'timestamp': '2020-08-09T10:38:07.379920'}
# 38 {'any': 'data38', 'timestamp': '2020-08-09T10:38:07.412286'}
# 39 {'any': 'data39', 'timestamp': '2020-08-09T10:38:07.443106'}
# 40 {'any': 'data40', 'timestamp': '2020-08-09T10:38:07.474822'}
# 41 {'any': 'data41', 'timestamp': '2020-08-09T10:38:07.504818'}
# 42 {'any': 'data42', 'timestamp': '2020-08-09T10:38:07.536181'}
# 43 {'any': 'data43', 'timestamp': '2020-08-09T10:38:07.568900'}
# 44 {'any': 'data44', 'timestamp': '2020-08-09T10:38:07.600504'}
# 45 {'any': 'data45', 'timestamp': '2020-08-09T10:38:07.632255'}
# 46 {'any': 'data46', 'timestamp': '2020-08-09T10:38:07.664480'}
# 47 {'any': 'data47', 'timestamp': '2020-08-09T10:38:07.695866'}
# 48 {'any': 'data48', 'timestamp': '2020-08-09T10:38:07.729452'}
# 49 {'any': 'data49', 'timestamp': '2020-08-09T10:38:07.759990'}
# 50 {'any': 'data50', 'timestamp': '2020-08-09T10:38:07.790988'}
# 51 {'any': 'data51', 'timestamp': '2020-08-09T10:38:07.821407'}
# 52 {'any': 'data52', 'timestamp': '2020-08-09T10:38:07.853550'}
# 53 {'any': 'data53', 'timestamp': '2020-08-09T10:38:07.884978'}
# 54 {'any': 'data54', 'timestamp': '2020-08-09T10:38:07.917488'}
# 55 {'any': 'data55', 'timestamp': '2020-08-09T10:38:07.952833'}
# 56 {'any': 'data56', 'timestamp': '2020-08-09T10:38:07.984287'}
# 57 {'any': 'data57', 'timestamp': '2020-08-09T10:38:08.014768'}
# 58 {'any': 'data58', 'timestamp': '2020-08-09T10:38:08.046658'}
# 59 {'any': 'data59', 'timestamp': '2020-08-09T10:38:08.077347'}
# 60 {'any': 'data60', 'timestamp': '2020-08-09T10:38:08.109309'}
# 61 {'any': 'data61', 'timestamp': '2020-08-09T10:38:08.140553'}
# 62 {'any': 'data62', 'timestamp': '2020-08-09T10:38:08.171025'}
# 63 {'any': 'data63', 'timestamp': '2020-08-09T10:38:08.201976'}
# 64 {'any': 'data64', 'timestamp': '2020-08-09T10:38:08.232805'}
# 65 {'any': 'data65', 'timestamp': '2020-08-09T10:38:08.264211'}
# 66 {'any': 'data66', 'timestamp': '2020-08-09T10:38:08.297140'}
# 67 {'any': 'data67', 'timestamp': '2020-08-09T10:38:08.329319'}
# 68 {'any': 'data68', 'timestamp': '2020-08-09T10:38:08.361555'}
# 69 {'any': 'data69', 'timestamp': '2020-08-09T10:38:08.393178'}
# 70 {'any': 'data70', 'timestamp': '2020-08-09T10:38:08.425233'}
# 71 {'any': 'data71', 'timestamp': '2020-08-09T10:38:08.457424'}
# 72 {'any': 'data72', 'timestamp': '2020-08-09T10:38:08.489605'}
# 73 {'any': 'data73', 'timestamp': '2020-08-09T10:38:08.521056'}
# 74 {'any': 'data74', 'timestamp': '2020-08-09T10:38:08.553189'}
# 75 {'any': 'data75', 'timestamp': '2020-08-09T10:38:08.585343'}
# 76 {'any': 'data76', 'timestamp': '2020-08-09T10:38:08.615968'}
# 77 {'any': 'data77', 'timestamp': '2020-08-09T10:38:08.648032'}
# 78 {'any': 'data78', 'timestamp': '2020-08-09T10:38:08.680091'}
# 79 {'any': 'data79', 'timestamp': '2020-08-09T10:38:08.710804'}
# 80 {'any': 'data80', 'timestamp': '2020-08-09T10:38:08.742155'}
# 81 {'any': 'data81', 'timestamp': '2020-08-09T10:38:08.773187'}
# 82 {'any': 'data82', 'timestamp': '2020-08-09T10:38:08.803861'}
# 83 {'any': 'data83', 'timestamp': '2020-08-09T10:38:08.834760'}
# 84 {'any': 'data84', 'timestamp': '2020-08-09T10:38:08.865810'}
# 85 {'any': 'data85', 'timestamp': '2020-08-09T10:38:08.897079'}
# 86 {'any': 'data86', 'timestamp': '2020-08-09T10:38:08.928366'}
# 87 {'any': 'data87', 'timestamp': '2020-08-09T10:38:08.958921'}
# 88 {'any': 'data88', 'timestamp': '2020-08-09T10:38:08.991757'}
# 89 {'any': 'data89', 'timestamp': '2020-08-09T10:38:09.022208'}
# 90 {'any': 'data90', 'timestamp': '2020-08-09T10:38:09.053371'}
# 91 {'any': 'data91', 'timestamp': '2020-08-09T10:38:09.086068'}
# 92 {'any': 'data92', 'timestamp': '2020-08-09T10:38:09.118213'}
# 93 {'any': 'data93', 'timestamp': '2020-08-09T10:38:09.151427'}
# 94 {'any': 'data94', 'timestamp': '2020-08-09T10:38:09.184150'}
# 95 {'any': 'data95', 'timestamp': '2020-08-09T10:38:09.217227'}
# 96 {'any': 'data96', 'timestamp': '2020-08-09T10:38:09.248512'}
# 97 {'any': 'data97', 'timestamp': '2020-08-09T10:38:09.281452'}
# 98 {'any': 'data98', 'timestamp': '2020-08-09T10:38:09.315351'}
# 99 {'any': 'data99', 'timestamp': '2020-08-09T10:38:09.349364'}

# %% [markdown]
# # Analyser

# %% [markdown]
# ### Types of Analysers:
# - Standard Analyzer
# - Simple Analyzer
# - Whitespace Analyzer
# - Stop Analyzer
# - Keyword Analyzer
# - Pattern Analyzer
# - Language Analyzer
# - Fingerprint Analyzer

# %% [markdown]
# ### NOTE OF FINGERPRINT ALGORITHM:
# It implements fingerprint algorithm which:
#
# - remove leading and trailing whitespace
# - change all characters to their lowercase representation
# - remove all punctuation and control characters
# - normalize extended western characters to their ASCII representation (for example "gödel" -> "godel")
# - split the string into whitespace-spparated tokens
# - sort the tokens and remove duplicates and join the tokens back together. For example, Hence, Mishra Amogh will be represented as amogh mishra

# %%
es.indices.analyze(body={
    "analyzer": "standard",
    "text": ['HELLO today is A GREAT DAY']
})
# remove uppercase letters
# Out:
# {'tokens': [{'token': 'hello',
#    'start_offset': 0,
#    'end_offset': 5,
#    'type': '<ALPHANUM>',
#    'position': 0},
#   {'token': 'today',
#    'start_offset': 6,
#    'end_offset': 11,
#    'type': '<ALPHANUM>',
#    'position': 1},
#   {'token': 'is',
#    'start_offset': 12,
#    'end_offset': 14,
#    'type': '<ALPHANUM>',
#    'position': 2},
#   {'token': 'a',
#    'start_offset': 15,
#    'end_offset': 16,
#    'type': '<ALPHANUM>',
#    'position': 3},
#   {'token': 'great',
#    'start_offset': 17,
#    'end_offset': 22,
#    'type': '<ALPHANUM>',
#    'position': 4},
#   {'token': 'day',
#    'start_offset': 23,
#    'end_offset': 26,
#    'type': '<ALPHANUM>',
#    'position': 5}]}

# %%
analyzer = ['standard','simple','whitespace','stop','keyword','pattern','fingerprint']

for analyze in analyzer:
    res = es.indices.analyze(body = {
        "analyzer": analyze,
        "text": ["HELLO WORLD. Today is the 2nd day of the week!!!!        it is Monday."]
    })
    print("====================", analyze, '==================')
    for i in res['tokens']:
        print(i['token'])
    print("\n")
# Out:
# ==================== standard ==================
# hello
# world
# today
# is
# the
# 2nd
# day
# of
# the
# week
# it
# is
# monday
#
#
# ==================== simple ==================
# hello
# world
# today
# is
# the
# nd
# day
# of
# the
# week
# it
# is
# monday
#
#
# ==================== whitespace ==================
# HELLO
# WORLD.
# Today
# is
# the
# 2nd
# day
# of
# the
# week!!!!
# it
# is
# Monday.
#
#
# ==================== stop ==================
# hello
# world
# today
# nd
# day
# week
# monday
#
#
# ==================== keyword ==================
# HELLO WORLD. Today is the 2nd day of the week!!!!        it is Monday.
#
#
# ==================== pattern ==================
# hello
# world
# today
# is
# the
# 2nd
# day
# of
# the
# week
# it
# is
# monday
#
#
# ==================== fingerprint ==================
# 2nd day hello is it monday of the today week world

# %%
# to specify analyzer while creating index
body = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0
    },
    "mappings": {
            "properties": {
                "text": {
                    "type" : "text",
                    "fields" : {
                        "english": {
                            "type": "text",
                            "analyzer": "english"
                        }
                    }
                }
            }
        }
}

#create index
es.indices.create(index = "chapter9-analyzer", ignore = 400, body = body)
# Out:
# {'acknowledged': True,
#  'shards_acknowledged': True,
#  'index': 'chapter9-analyzer'}

# %%
res = es.indices.analyze(index = "chapter9-analyzer", body = {
    "field": "text.english",
    "text": "The quick Brown Foxes."
})
for i in res['tokens']:
    print(i['token'])
# Out:
# The
# quick
# Brown
# Foxes.

# %%
es.indices.delete(index = "chapter9-analyzer")
# Out:
# {'acknowledged': True}
